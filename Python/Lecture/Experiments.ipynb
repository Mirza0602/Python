# %%
from graphviz import Digraph, Graph

# %%
from graphviz import Digraph
dot = Digraph()
top = Digraph()
down = Digraph()
top.graph_attr.update(rank="same")
down.graph_attr.update(rank="same")
top.node('A', 'If condition',shape="diamond")
top.node('B', 'Else',shape="diamond")
dot.node('C', 'Instructions',shape="box")
dot.node('D', 'Instructions',shape="box")
dot.node('In','',shape="point")
down.node('Out2','',shape="point")
down.node('Out','',shape="point")
#dot.node('A', '<f0> a | <f1> b | <f2> c | <f3> d| <f4> e ',shape="record",color="blue")
dot.edge('In','A')
top.edge('A', 'B')
dot.edge('A', 'C')
dot.edge('B', 'D')
dot.edge('C','Out')
dot.edge('D','Out2')
#dot.edge('Out2','Out')
dot.subgraph(top)
dot.subgraph(down)
dot

# %%
dot = Digraph(comment='The Round Table')
dot.node('A', 'King Arthur',shape="record",color="blue")
dot.node('B', 'Sir Bedevere the Wise')
dot.node('L', 'Sir Lancelot the Brave')

dot.edges(['AB', 'AL'])
dot.edge('B', 'L', constraint='false')
dot

# %%
dot = Digraph()
dot.node('B', 'ref1')
dot.node('A', '<f0> a | <f1> b | <f2> c | <f3> d| <f4> e ',shape="record",color="blue")
dot.edge('B', 'A:f0')
dot

# %%
dot2 = Digraph()
dot2.node('B', 'ref1')
dot2.node('L', 'ref2')
dot2.node('A', '<f0> a | <f1> b | <f2> c | <f3> d| <f4> e ',shape="record",color="blue")


#dot.edges(['BA', 'LA'])
#dot.edge('B', 'A:f1', constraint='false')
dot2.edge('B', 'A:f0')
dot2.edge('L', 'A:f0')
dot2

# %%
dot.render('test-output/round-table.gv', view=True)
# Out:
# 'test-output/round-table.gv.pdf'

# %%
dot3 = Digraph()
dot3.node('B', 'ref1')
#dot2.node('L', 'ref2')
dot3.node('A', '<f0> a | <f1> b | <f2> c | <f3> d| <f4> e ',shape="record",color="blue")

dot3.node('C', 'ref2')
#dot2.node('L', 'ref2')
dot3.node('D', '<f0> a | <f1> b | <f2> c | <f3> d| <f4> e ',shape="record",color="blue")

#dot.edges(['BA', 'LA'])
#dot.edge('B', 'A:f1', constraint='false')
dot3.edge('B', 'A:f0')
dot3.edge('C', 'D:f0')
dot3

# %%
dot3 = Digraph()
dot3.node('B', 'ref1')
#dot2.node('L', 'ref2')
dot3.node('A', '<f0> a | <f1> b | <f2> c | <f3> d| <f4> e ',shape="record",color="blue")

dot3.node('C', 'ref2')
#dot2.node('L', 'ref2')
dot3.node('D', '<f0> a | <f1> b | <f2> c | <f3> d| <f4> e ',shape="record",color="blue")

dot3.node('E', '<f0> x | <f1> y | <f2> z ',shape="record",color="green")
#dot.edges(['BA', 'LA'])
#dot.edge('B', 'A:f1', constraint='false')
dot3.edge('B', 'A:f0')
dot3.edge('C', 'D:f0')
dot3.edge('A:f1', 'E:f0')
dot3.edge('D:f1', 'E:f0')
dot3

# %%
dot3 = Digraph()
dot3.node('B', 'ref1')
#dot2.node('L', 'ref2')
dot3.node('A', '<f0> a | <f1> b | <f2> c | <f3> d| <f4> e ',shape="record",color="blue")

dot3.node('C', 'ref2')
#dot2.node('L', 'ref2')
dot3.node('D', '<f0> a | <f1> b | <f2> c | <f3> d| <f4> e ',shape="record",color="blue")

dot3.node('E', '<f0> x | <f1> y | <f2> z ',shape="record",color="green")
dot3.node('F', '<f0> x | <f1> y | <f2> z ',shape="record",color="green")
#dot.edges(['BA', 'LA'])
#dot.edge('B', 'A:f1', constraint='false')
dot3.edge('B', 'A:f0')
dot3.edge('C', 'D:f0')
dot3.edge('A:f1', 'E:f0')
dot3.edge('D:f1', 'F:f0')
dot3

# %%
from graphviz import Source
src = Source('digraph "the holy hand grenade" { rankdir=LR; 1 -> 2 -> 3 -> lob }')
src

# %%
digraph g {
graph [
rankdir = "LR"
];
node [
fontsize = "16"
shape = "ellipse"
];
edge [
];
"node0" [
label = "<f0> 0x10ba8| <f1>"
shape = "record"
];
"node1" [
label = "<f0> 0xf7fc4380| <f1> | <f2> |-1"
shape = "record"
];
"node2" [
label = "<f0> 0xf7fc44b8| | |2"
shape = "record"
];
"node3" [
label = "<f0> 3.43322790286038071e-06|44.79998779296875|0"
shape = "record"
];
"node4" [
label = "<f0> 0xf7fc4380| <f1> | <f2> |2"
shape = "record"
];
}
# Out:
#   File "<ipython-input-11-e0180b1596f5>", line 1
#     digraph g {
#             ^
# SyntaxError: invalid syntax

# %%
from bs4 import BeautifulSoup
import requests

# %%
r=requests.get("https://de.wikipedia.org/wiki/Stuttgart")

# %%
soup=BeautifulSoup(r.text,"html.parser")
soup
for c in soup.findAll('table'):
    #if c.has_attr('role'):
    print(c.text.split())
    print("-"*20)
# Out:
# ['Der', 'Titel', 'dieses', 'Artikels', 'ist', 'mehrdeutig.', 'Weitere', 'Bedeutungen', 'sind', 'unter', 'Stuttgart', '(Begriffsklärung)', 'aufgeführt.']
# --------------------
# ...

# %%
#r.text.find("Infobox")
# Out:
# 11092

# %%
r.text[11092:11190]
# Out:
# 'Infobox Gemeinde in Deutschland\n|Art              = Stadt\n|Wappen           = Coat of arms of Stut'
