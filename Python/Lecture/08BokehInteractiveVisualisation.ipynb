# %% [markdown]
# # Interactive Plotting with Bokeh
# * Author: Johannes Maucher
# * Last update: 03.05.2018

# %%
import pandas as pd
#import bokeh
from IPython.display import display
from bokeh.plotting import figure 
from bokeh.io import output_notebook, show
from bokeh.models import ColumnDataSource,HoverTool

# %%
germanFood=pd.read_csv("germanProductSubset.csv",index_col=0)

# %%
display(germanFood.head(20))
print(germanFood.shape)
# Out:
#                                                brands  \
# 0                                         Candy Crush
# 1                                         Candy Crush
# 2                                           Del Monte
# 4                                  The Invisible Chef
# 8                                  The Invisible Chef
# 11                                            vitasia
# 12                              Sun Snacks (Aldi Süd)
# 14                                           Bergader
# 15                                               Ikea
# 16      Freihofer Gourmet,Aldi Einkauf GmbH & Co. oHG
# 23  Moser-Roth,Aldi GmbH & Co. KG,Aldi Einkauf Gmb...
# 24  Moser-Roth,Aldi GmbH & Co. KG,Aldi Einkauf Gmb...
# 25              Scholetta,Aldi Einkauf GmbH & Co. oHG
# 30                                            Milbona
# 31                                            Combino
# 32                             Freshona, Fresh & Easy
# 33                           Nürnberger-Wein-Kellerei
# 34  Fin Carré,Lidl Stiftung & Co. KG,Schwarz Betei...
# 35                            Saint Alby,Gebirgsjäger
# 36                                      Envia,Milbona
#
#                                          product_name  \
# 0                                  Sour Fruit Gummies
# 1                                          Jelly Fish
# 2                           Ananas Scheiben gezuckert
# 4                Pancake & Waffle Mix Lemon Blueberry
# 8                     Pancake & Waffle Mix Buttermilk
# 11                    Thai Noodles sweet & sour sauce
# 12                                        Salzstangen
# 14                                           Edelpilz
# 15                                     Rye crispbread
# 16           Edelbitterschokolade Sao Thomé 75% Kakao
# 23         Edel-Zartbitterschokolade Minze 52 % Kakao
# 24         Edel-Zartbitterschokolade Chili 52 % Kakao
# 25  Zarbitter Schokolade mit gerösteten Mandelstüc...
# 30                                        Schlagsahne
# 31                            Sauce tomate bolognaise
# 32                                         Cornichons
# 33                               Christkindl Glühwein
# 34                           Dark chocolate 50% cocoa
# 35                                          Bockwurst
# 36                              Crème Entière liquide
#
#                          main_category  energy_100g  fat_100g  proteins_100g  \
# 0                     en:sugary-snacks       1360.0       0.0            5.0
# 1                     en:sugary-snacks        586.0       0.0            0.0
# 2   en:plant-based-foods-and-beverages        322.0       0.0            0.0
# 4                       en:pancake-mix        852.0       1.0            6.0
# 8                       en:pancake-mix        962.0       0.0            7.0
# 11  en:plant-based-foods-and-beverages        617.0       2.6            3.9
# 12                     en:salty-snacks       1583.0       4.2           11.0
# 14                          en:dairies       1376.0      28.0           19.5
# 15  en:plant-based-foods-and-beverages       1463.0       2.6            9.0
# 16                    en:sugary-snacks       2314.0      42.5            9.0
# 23                    en:sugary-snacks       2284.0      34.5            4.5
# 24                    en:sugary-snacks       2275.0      34.4            4.5
# 25                    en:sugary-snacks       2307.0      37.0            7.1
# 30                          en:dairies       1207.0      30.0            2.5
# 31                        en:groceries        352.0       4.3            3.9
# 32                          en:pickles        148.0       0.3            1.2
# 33                         en:gluhwein        365.5       0.1            0.1
# 34                    en:sugary-snacks       2180.0      31.8            5.4
# 35                            en:meats       1165.0      25.0           12.0
# 36                          en:dairies       1209.0      30.0            2.4
#
#     salt_100g  carbohydrates_100g  sugars_100g  sodium_100g  \
# 0     0.12700               75.00        57.50     0.050000
# 1     0.07620               34.00        24.00     0.030000
# 2     0.02286               19.66        17.95     0.009000
# 4     1.33000               42.00         8.00     0.523622
# 8     1.57000               49.00        13.00     0.618110
# 11    0.75000               26.30         7.00     0.295276
# 12    6.70000               71.00         2.30     2.637795
# 14    3.50000                0.50         0.30     1.377953
# 15    1.20000               64.00         1.30     0.472441
# 16    0.02540               27.60        21.90     0.010000
# 23    0.01000               51.50        48.30     0.003937
# 24    0.01000               51.40        48.20     0.003937
# 25    0.01000               44.10        39.90     0.003937
# 30    0.08000                3.20         3.20     0.031496
# 31    1.40000                6.80         5.10     0.551181
# 32    1.23000                5.50         5.40     0.484252
# 33    0.10000                8.60         8.60     0.039370
# 34    0.01000               49.60        47.10     0.003937
# 35    1.94000                2.00         1.00     0.763780
# 36    0.08000                3.40         3.40     0.031496
#
#     saturated-fat_100g
# 0                  0.0
# 1                  0.0
# 2                  0.0
# 4                  0.0
# 8                  0.0
# 11                 0.6
# 12                 1.6
# 14                19.3
# 15                 0.6
# 16                26.6
# 23                20.9
# 24                20.9
# 25                19.3
# 30                20.0
# 31                 1.8
# 32                 0.1
# 33                 0.1
# 34                19.1
# 35                 9.9
# 36                21.0
# (466, 11)

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="6eba1cbb-1e0d-4068-b2a2-4b7f0e413840">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Simple 2D-Plot with interactive tools

# %%
source = ColumnDataSource(germanFood)
options = dict(plot_width=800, plot_height=500,
               tools="pan,wheel_zoom,box_zoom,box_select,lasso_select,reset")

p = figure(title="carbohydrates vs. sugar", x_axis_label="carbohydrates/100g", y_axis_label="sugars/100g", **options)
p.circle("carbohydrates_100g","sugars_100g", color="blue", size=8, alpha=0.4, source=source)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e45125fe-723e-4044-b2d5-2e8578f80256"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("e45125fe-723e-4044-b2d5-2e8578f80256");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e45125fe-723e-4044-b2d5-2e8578f80256");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e45125fe-723e-4044-b2d5-2e8578f80256' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"5fb724e1-6c0b-4709-9093-7e38fd627fca":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"xs_units":"screen","ys_units":"screen"},"id":"d6268b4e-3819-405c-9be2-fe8134611663","type":"PolyAnnotation"},{"attributes":{},"id":"2b27d765-b369-458a-8caf-f1d2ace25c7b","type":"BasicTicker"},{"attributes":{"plot":null,"text":"carbohydrates vs. sugar"},"id":"b239f925-f36b-47eb-8ab6-4625b0e8c401","type":"Title"},{"attributes":{"callback":null,"column_names":["brands","product_name","main_category","energy_100g","fat_100g","proteins_100g","salt_100g","carbohydrates_100g","sugars_100g","sodium_100g","saturated-fat_100g","index"],"data":{"brands":["Candy Crush","Candy Crush","Del Monte","The Invisible Chef","The Invisible Chef","vitasia","Sun Snacks (Aldi S\u00fcd)","Bergader","Ikea","Freihofer Gourmet,Aldi Einkauf GmbH & Co. oHG","Moser-Roth,Aldi GmbH & Co. KG,Aldi Einkauf GmbH & Co. oHG","Moser-Roth,Aldi GmbH & Co. KG,Aldi Einkauf GmbH & Co. oHG","Scholetta,Aldi Einkauf GmbH & Co. oHG","Milbona","Combino","Freshona, Fresh & Easy","N\u00fcrnberger-Wein-Kellerei","Fin Carr\u00e9,Lidl Stiftung & Co. KG,Schwarz Beteiligungs GmbH,Solent GmbH","Saint Alby,Gebirgsj\u00e4ger","Envia,Milbona","Alesto","eridanous,Milbona","Alesto","Naturgut,Penny","Vitasia China","Bio Sonne,Soja Food","Combino","Naturgut,Giaguaro","J.D. Gross","Crownfield,Lidl","Milbona","Gutknecht","Lovilio","Mister choc","vitasia","Landjunker","NIXE,Lidl","Kania","Fin Carr\u00e9,//Property://,Lidl Stiftung & Co. KG,//Die Zugeh\u00f6rigkeit zu://,Schwarz Beteiligungs GmbH","Fin Carr\u00e9,//Property://,Lidl Stiftung & Co. KG,//Die Zugeh\u00f6rigkeit zu://,Schwarz Beteiligungs GmbH","Kania","Milbona","Milbona","J.D.Gross,Halloren Schokoladenfabrik AG","Milbona","Milbona","Milbona","Milbona","My Best Veggie","My Best Veggie","Golden Sun","Crownfield,LIDL","Riggano","bio","Moser-Roth,Aldi GmbH & Co. KG,Aldi Einkauf GmbH & Co. oHG","milfina, M Classic","Choceur,Hosta","Grandessa","Genuss der Saison","EDEKA","Puda","Paradiso","Oster Phantasie","Naturgut","Alpenhain","Trader Joe's","Scholetta,Aldi Einkauf GmbH & Co. oHG","Freihofer Gourmet,Aldi Einkauf GmbH & Co. oHG","Mein Veggie Tag","Milsani","GutBio","Trader Joe's","Ferrero,Nutella","Salakis","Lindt, Lindt Excellence","Lindt,Chocoladefabriken Lindt & Spr\u00fcngli AG,Lindt Excellence","Leerdammer","Leerdammer","Bonduelle","Bonduelle","Bonduelle","Haribo","Pr\u00e9sident","P\u00e8re Eug\u00e8ne","Pr\u00e9sident","Ponthier","Chavroux","Les anis de flavigny,Anis de Flavigny","Nesquik,Nestle","H\u00e4agen-Dasz","H\u00e4agen-Dazs","Aoste","Salakis","Nestle,KitKat","Sweet+Plus","Dr. Willi Knoll","Schneekoppe","Bertolli,Unilever","Bertolli","Pommersche,R\u00fcgenwalder M\u00fchle,R\u00fcgenwalder","R\u00fcgenwalder M\u00fchle","Grafschafter,Grafschafter Krautfabrik","Ritter Sport","Ritter Sport","Ritter Sport,Ritter Sport Bunte Vielfalt","L\u00e4tta","Dr. Oetker","Lindt","Lindt","K\u00f6ln Cerealien","K\u00f6lln Balance","Mounthagen","Schapfen M\u00fchle","Leicht & Cross","Leicht & Cross","Leicht & Cross","Leicht & Cross","Haribo","Dr. Oetker,Pizzaburger","Kerrygold","Wiltmann","Me\u00dfmer","M\u00f6venpick","Uncle Ben's","Ehrmann","Ehrmann","Elinas","Kellogg's","Rabenhorst plus","Soja Fit","Berief","Barney's Best","Barney's Best","Bio-Zentrale","Biovegan","Biovegan","Biovegan","Rosengarten","Rapunzel","Rapunzel,Klare Suppe","Rapunzel","Bergader","Bergader","Bergader","TOP MARE","Multipower","Develey","Lambertz","Maryland","M\u00f6venpick","Seeberger","Seeberger","Seeberger","Seeberger","FRoSTA","FRoSTA","FRoSTA","FRoSTA","FRoSTA","FRoSTA","FRoSTA","FRoSTA","FRoSTA","FRoSTA","Seitenbacher","Kinder","Kinder,Ferrero","Ferrero,duplo","Ferrero,Duplo","Nutella,Ferrero","Kinder,Ferrero","Leicht & Cross","Leicht & Cross","S\u00f6bbeke","Milc ...

# %% [markdown]
# **Conclusions from the plot above:**
# * sugar is a form of carbohydrate, but not the only one

# %%
p = figure(title="Proteins vs. Carbohydrates", x_axis_label="carbohydrates/100g", y_axis_label="proteins/100g", **options)
p.circle("carbohydrates_100g","proteins_100g", color="blue", size=8, alpha=0.4, source=source)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e249fba9-34a0-4a92-ac85-90f00f1082d0"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("e249fba9-34a0-4a92-ac85-90f00f1082d0");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e249fba9-34a0-4a92-ac85-90f00f1082d0");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e249fba9-34a0-4a92-ac85-90f00f1082d0' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"fd597097-5208-4be2-9e76-88e4204c3944":{"roots":{"references":[{"attributes":{"axis_label":"proteins/100g","formatter":{"id":"579542f7-85c4-4642-b1da-b7a83e49b143","type":"BasicTickFormatter"},"plot":{"id":"ada568d7-973e-4500-b8a5-78dc5deb8eb0","subtype":"Figure","type":"Plot"},"ticker":{"id":"4d98467b-e934-4522-a9fd-0d87f8dc00a3","type":"BasicTicker"}},"id":"c298c2eb-7475-40d5-abab-d2838ceb2731","type":"LinearAxis"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"41717d88-8a88-432f-a1cf-08bebfd48d98","type":"BoxAnnotation"},{"attributes":{"dimension":1,"plot":{"id":"ada568d7-973e-4500-b8a5-78dc5deb8eb0","subtype":"Figure","type":"Plot"},"ticker":{"id":"4d98467b-e934-4522-a9fd-0d87f8dc00a3","type":"BasicTicker"}},"id":"c95764d4-2735-4eb1-a267-9da4f9922723","type":"Grid"},{"attributes":{"plot":{"id":"ada568d7-973e-4500-b8a5-78dc5deb8eb0","subtype":"Figure","type":"Plot"}},"id":"65843918-d587-43c4-9314-7800d5acfb22","type":"ResetTool"},{"attributes":{"callback":null,"column_names":["brands","product_name","main_category","energy_100g","fat_100g","proteins_100g","salt_100g","carbohydrates_100g","sugars_100g","sodium_100g","saturated-fat_100g","index"],"data":{"brands":["Candy Crush","Candy Crush","Del Monte","The Invisible Chef","The Invisible Chef","vitasia","Sun Snacks (Aldi S\u00fcd)","Bergader","Ikea","Freihofer Gourmet,Aldi Einkauf GmbH & Co. oHG","Moser-Roth,Aldi GmbH & Co. KG,Aldi Einkauf GmbH & Co. oHG","Moser-Roth,Aldi GmbH & Co. KG,Aldi Einkauf GmbH & Co. oHG","Scholetta,Aldi Einkauf GmbH & Co. oHG","Milbona","Combino","Freshona, Fresh & Easy","N\u00fcrnberger-Wein-Kellerei","Fin Carr\u00e9,Lidl Stiftung & Co. KG,Schwarz Beteiligungs GmbH,Solent GmbH","Saint Alby,Gebirgsj\u00e4ger","Envia,Milbona","Alesto","eridanous,Milbona","Alesto","Naturgut,Penny","Vitasia China","Bio Sonne,Soja Food","Combino","Naturgut,Giaguaro","J.D. Gross","Crownfield,Lidl","Milbona","Gutknecht","Lovilio","Mister choc","vitasia","Landjunker","NIXE,Lidl","Kania","Fin Carr\u00e9,//Property://,Lidl Stiftung & Co. KG,//Die Zugeh\u00f6rigkeit zu://,Schwarz Beteiligungs GmbH","Fin Carr\u00e9,//Property://,Lidl Stiftung & Co. KG,//Die Zugeh\u00f6rigkeit zu://,Schwarz Beteiligungs GmbH","Kania","Milbona","Milbona","J.D.Gross,Halloren Schokoladenfabrik AG","Milbona","Milbona","Milbona","Milbona","My Best Veggie","My Best Veggie","Golden Sun","Crownfield,LIDL","Riggano","bio","Moser-Roth,Aldi GmbH & Co. KG,Aldi Einkauf GmbH & Co. oHG","milfina, M Classic","Choceur,Hosta","Grandessa","Genuss der Saison","EDEKA","Puda","Paradiso","Oster Phantasie","Naturgut","Alpenhain","Trader Joe's","Scholetta,Aldi Einkauf GmbH & Co. oHG","Freihofer Gourmet,Aldi Einkauf GmbH & Co. oHG","Mein Veggie Tag","Milsani","GutBio","Trader Joe's","Ferrero,Nutella","Salakis","Lindt, Lindt Excellence","Lindt,Chocoladefabriken Lindt & Spr\u00fcngli AG,Lindt Excellence","Leerdammer","Leerdammer","Bonduelle","Bonduelle","Bonduelle","Haribo","Pr\u00e9sident","P\u00e8re Eug\u00e8ne","Pr\u00e9sident","Ponthier","Chavroux","Les anis de flavigny,Anis de Flavigny","Nesquik,Nestle","H\u00e4agen-Dasz","H\u00e4agen-Dazs","Aoste","Salakis","Nestle,KitKat","Sweet+Plus","Dr. Willi Knoll","Schneekoppe","Bertolli,Unilever","Bertolli","Pommersche,R\u00fcgenwalder M\u00fchle,R\u00fcgenwalder","R\u00fcgenwalder M\u00fchle","Grafschafter,Grafschafter Krautfabrik","Ritter Sport","Ritter Sport","Ritter Sport,Ritter Sport Bunte Vielfalt","L\u00e4tta","Dr. Oetker","Lindt","Lindt","K\u00f6ln Cerealien","K\u00f6lln Balance","Mounthagen","Schapfen M\u00fchle","Leicht & Cross","Leicht & Cross","Leicht & Cross","Leicht & Cross","Haribo","Dr. Oetker,Pizzaburger","Kerrygold","Wiltmann","Me\u00dfmer","M\u00f6venpick ...

# %% [markdown]
# **Improvements:**
# * For a given point, we want to
#     * determine the coordinates more accurately
#     * know the name of the corresponding product

# %%
hover = HoverTool(tooltips = [("Productname","@product_name"),("Brand","@brands")], mode="mouse") #other modes: vline, hline
options = dict(plot_width=800, plot_height=500,
               tools=[hover,"crosshair,pan,wheel_zoom,box_zoom,box_select,lasso_select,reset"])

p = figure(title="Proteins vs. Carbohydrates", x_axis_label="carbohydrates/100g", y_axis_label="proteins/100g", **options)
p.circle("carbohydrates_100g","proteins_100g", color="blue", size=8, alpha=0.4, source=source)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="2a8ce9e9-66a2-423a-a9ab-50e5e62870d8"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("2a8ce9e9-66a2-423a-a9ab-50e5e62870d8");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("2a8ce9e9-66a2-423a-a9ab-50e5e62870d8");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '2a8ce9e9-66a2-423a-a9ab-50e5e62870d8' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"c44ca383-5af5-4083-a4c8-69bcddace760":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"0101445d-8899-4fc1-8e07-aeb99f9202cb","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"04979e19-ce11-4501-bc46-b0785b833da5","type":"ColumnDataSource"},"glyph":{"id":"e82755ae-1857-4f81-8a10-76a79248773d","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"0d2cbd5b-5603-4fe7-8b5d-983a31237839","type":"Circle"},"selection_glyph":null},"id":"e7f4c245-80c3-4637-a8cc-b8b0ac264bcb","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["brands","product_name","main_category","energy_100g","fat_100g","proteins_100g","salt_100g","carbohydrates_100g","sugars_100g","sodium_100g","saturated-fat_100g","index"],"data":{"brands":["Candy Crush","Candy Crush","Del Monte","The Invisible Chef","The Invisible Chef","vitasia","Sun Snacks (Aldi S\u00fcd)","Bergader","Ikea","Freihofer Gourmet,Aldi Einkauf GmbH & Co. oHG","Moser-Roth,Aldi GmbH & Co. KG,Aldi Einkauf GmbH & Co. oHG","Moser-Roth,Aldi GmbH & Co. KG,Aldi Einkauf GmbH & Co. oHG","Scholetta,Aldi Einkauf GmbH & Co. oHG","Milbona","Combino","Freshona, Fresh & Easy","N\u00fcrnberger-Wein-Kellerei","Fin Carr\u00e9,Lidl Stiftung & Co. KG,Schwarz Beteiligungs GmbH,Solent GmbH","Saint Alby,Gebirgsj\u00e4ger","Envia,Milbona","Alesto","eridanous,Milbona","Alesto","Naturgut,Penny","Vitasia China","Bio Sonne,Soja Food","Combino","Naturgut,Giaguaro","J.D. Gross","Crownfield,Lidl","Milbona","Gutknecht","Lovilio","Mister choc","vitasia","Landjunker","NIXE,Lidl","Kania","Fin Carr\u00e9,//Property://,Lidl Stiftung & Co. KG,//Die Zugeh\u00f6rigkeit zu://,Schwarz Beteiligungs GmbH","Fin Carr\u00e9,//Property://,Lidl Stiftung & Co. KG,//Die Zugeh\u00f6rigkeit zu://,Schwarz Beteiligungs GmbH","Kania","Milbona","Milbona","J.D.Gross,Halloren Schokoladenfabrik AG","Milbona","Milbona","Milbona","Milbona","My Best Veggie","My Best Veggie","Golden Sun","Crownfield,LIDL","Riggano","bio","Moser-Roth,Aldi GmbH & Co. KG,Aldi Einkauf GmbH & Co. oHG","milfina, M Classic","Choceur,Hosta","Grandessa","Genuss der Saison","EDEKA","Puda","Paradiso","Oster Phantasie","Naturgut","Alpenhain","Trader Joe's","Scholetta,Aldi Einkauf GmbH & Co. oHG","Freihofer Gourmet,Aldi Einkauf GmbH & Co. oHG","Mein Veggie Tag","Milsani","GutBio","Trader Joe's","Ferrero,Nutella","Salakis","Lindt, Lindt Excellence","Lindt,Chocoladefabriken Lindt & Spr\u00fcngli AG,Lindt Excellence","Leerdammer","Leerdammer","Bonduelle","Bonduelle","Bonduelle","Haribo","Pr\u00e9sident","P\u00e8re Eug\u00e8ne","Pr\u00e9sident","Ponthier","Chavroux","Les anis de flavigny,Anis de Flavigny","Nesquik,Nestle","H\u00e4agen-Dasz","H\u00e4agen-Dazs","Aoste","Salakis","Nestle,KitKat","Sweet+Plus","Dr. Willi Knoll","Schneekoppe","Bertolli,Unilever","Bertolli","Pommersche,R\u00fcgenwalder M\u00fchle,R\u00fcgenwalder","R\u00fcgenwalder M\u00fchle","Grafschafter,Grafschafter Krautfabrik","Ritter Sport","Ritter Sport","Ritter Sport,Ritter Sport Bunte Vielfalt","L\u00e4tta","Dr. Oetker","Lindt","Lindt","K\u00f6ln Cerealien","K\u00f6lln Balance","Mounthagen","Schapfen M\u00fchle","Leicht & Cross","Leicht & Cross","Leicht & Cross","Leicht & Cross","Haribo","Dr. Oetker,Pizzaburger","Kerrygold","Wiltmann","Me\u00dfmer","M\u00f6venpick","Uncle Ben's","Ehrmann","Ehrmann","Elinas","Kellogg's","Rabenhorst plus","Soja Fit","Berief","Barney's Best","Barney's Best","Bio-Zentrale","Biovegan","Biovegan","Biovegan","Rosengarten","Rapunzel","Rapunzel,Klare Suppe","Rapunzel","Bergader","Bergader","Bergader","TOP MARE","Multipower","Develey","Lambertz","Maryland","M\u00f6venpick","Seeberger","Seeberger","Seeberger","Seeberger","FR ...

# %% [markdown]
# ## Encode further information in marker size- and color
# As demonstrated in the example above, each single point in the 2-dimensional plot encodes at least two feature-values. It's first component is the value of the first feature and the second is it's value of the second feature. Moreover, we can also annotate each point with textual information. In the example above, the `HoverTool` has been applied to display for each point two further feature-values: *product_name* and *brand*. Further information (feature values) can be visualized by the size and color of single points. This is demonstrated below, where
# * the marker-size shall encode the value of the feature `energy_100g`
# * the marker-color shall encode the value of the feature `fat_100g`
#
# ### Use marker-size to encode further information
# In order to encode the `energy_100g`-values by the marker size,
#
# 1. we scale the `energy_100g`-values into a range, which is suitable for marker sizes. This is done by first dividing all values by the maximum value. After this devision all values are $\leq 1$. Then all scaled values are multiplied by an integer, here $E=30$, which shall be the maximum marker size.
# 2. the scaled values are assigned to a new column, here `normedEnergy`, of the dataframe.
# 3. the new column `normedEnergy` is assigned to the `scale`-argument of the `circle()`-method.

# %%
import numpy as np
energy=germanFood["energy_100g"].values.astype(int)
maxEnergy=np.max(energy)
normedEnergy=energy/maxEnergy
E=30
germanFood["normedEnergy"]=E*normedEnergy
source = ColumnDataSource(germanFood)

# %%
hover = HoverTool(tooltips = [("Productname","@product_name"),("Brand","@brands")], mode="mouse") #other modes: vline, hline
options = dict(plot_width=800, plot_height=500,
               tools=[hover,"crosshair,pan,wheel_zoom,box_zoom,box_select,lasso_select,reset"])

p = figure(title="Proteins vs. Carbohydrates", x_axis_label="carbohydrates/100g", y_axis_label="proteins/100g", **options)
p.circle("carbohydrates_100g","proteins_100g", size="normedEnergy", color="blue", alpha=0.4, source=source)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="66b08e13-2cc9-4ba6-b24b-3fde2c5827fa"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("66b08e13-2cc9-4ba6-b24b-3fde2c5827fa");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("66b08e13-2cc9-4ba6-b24b-3fde2c5827fa");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '66b08e13-2cc9-4ba6-b24b-3fde2c5827fa' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"9e8df0d7-879b-44d8-b630-ab20f5e12abd":{"roots":{"references":[{"attributes":{"callback":null,"plot":{"id":"f383942f-cbfc-483a-9607-540c408ada9f","subtype":"Figure","type":"Plot"},"tooltips":[["Productname","@product_name"],["Brand","@brands"]]},"id":"1577beb7-0b17-4cf2-90a8-2d492ec3e57f","type":"HoverTool"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"xs_units":"screen","ys_units":"screen"},"id":"d8fad45e-d8c1-41b1-b355-67f6911d5102","type":"PolyAnnotation"},{"attributes":{},"id":"de1a19cf-9cc5-41e9-83a2-bc15ba0257ba","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"value":0.4},"fill_color":{"value":"blue"},"line_alpha":{"value":0.4},"line_color":{"value":"blue"},"size":{"field":"normedEnergy","units":"screen"},"x":{"field":"carbohydrates_100g"},"y":{"field":"proteins_100g"}},"id":"add4b35b-47b6-4ee3-a339-3b54fdddd391","type":"Circle"},{"attributes":{"axis_label":"proteins/100g","formatter":{"id":"de1a19cf-9cc5-41e9-83a2-bc15ba0257ba","type":"BasicTickFormatter"},"plot":{"id":"f383942f-cbfc-483a-9607-540c408ada9f","subtype":"Figure","type":"Plot"},"ticker":{"id":"2a5bf881-e22f-4111-b415-2b918f71781a","type":"BasicTicker"}},"id":"1f1d3e4b-4a0a-4a16-898b-36273222fb12","type":"LinearAxis"},{"attributes":{"overlay":{"id":"af54579d-3e1e-4111-8492-d5bf8e8acf90","type":"BoxAnnotation"},"plot":{"id":"f383942f-cbfc-483a-9607-540c408ada9f","subtype":"Figure","type":"Plot"}},"id":"2ba6a6f3-2021-4073-bb8d-2ba170ed71cb","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"f383942f-cbfc-483a-9607-540c408ada9f","subtype":"Figure","type":"Plot"}},"id":"8d87e811-e61c-417c-a451-1f63c56a13e2","type":"ResetTool"},{"attributes":{"plot":{"id":"f383942f-cbfc-483a-9607-540c408ada9f","subtype":"Figure","type":"Plot"}},"id":"ba58b421-f929-46a4-8137-57c038100d8a","type":"WheelZoomTool"},{"attributes":{"below":[{"id":"48326ea8-2496-4de1-acbd-2a6430e2be2a","type":"LinearAxis"}],"left":[{"id":"1f1d3e4b-4a0a-4a16-898b-36273222fb12","type":"LinearAxis"}],"plot_height":500,"plot_width":800,"renderers":[{"id":"48326ea8-2496-4de1-acbd-2a6430e2be2a","type":"LinearAxis"},{"id":"c71453f5-d55c-491a-861a-4e2df9a7c182","type":"Grid"},{"id":"1f1d3e4b-4a0a-4a16-898b-36273222fb12","type":"LinearAxis"},{"id":"131a9c42-7880-4634-9873-487870b5882b","type":"Grid"},{"id":"af54579d-3e1e-4111-8492-d5bf8e8acf90","type":"BoxAnnotation"},{"id":"c41809a7-aca9-4754-b33c-5112d1a84b57","type":"BoxAnnotation"},{"id":"d8fad45e-d8c1-41b1-b355-67f6911d5102","type":"PolyAnnotation"},{"id":"303dc066-073d-492c-a665-a769d3e1ce3e","type":"GlyphRenderer"}],"title":{"id":"955f2c49-f7b7-4290-a273-9fd49f08bc14","type":"Title"},"tool_events":{"id":"d069750b-ff25-46a8-bee7-892037d98110","type":"ToolEvents"},"toolbar":{"id":"c7af8daf-9a99-4509-a609-be24206781c8","type":"Toolbar"},"x_range":{"id":"5dbf862e-6143-4a1f-93e3-cff57938802a","type":"DataRange1d"},"y_range":{"id":"834aea32-a122-4951-853e-c4f9f4d7701e","type":"DataRange1d"}},"id":"f383942f-cbfc-483a-9607-540c408ada9f","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"d069750b-ff25-46a8-bee7-892037d98110","type":"ToolEvents"},{"attributes":{"plot":{"id":"f383942f-cbfc-483a-9607-540c408ada9f","subtype":"Figure","type":"Plot"}},"id":"7a3c6136-3d60-4782-97f5-64e4137c8a0b","type":"PanTool"},{"attributes":{},"id":"ec8ed532-a786-4457-982f-35a4133f2bf6","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["brands","product_name","main_category","energy_100g","fat_100g","proteins_100g","salt_100g","carbohydrates_100g","sugars_100g","sodium_100g","saturated-fat_100g","normedEnergy","index"],"data":{"brands":["Candy Crush","Candy Crush","Del Monte","The Invisible Chef","The Invisible Chef","vitasia","Sun Snacks (Aldi S\u00fcd)","Bergader","Ikea","Freihofer Gourmet,Aldi Einkauf GmbH & Co. oHG","Moser-Roth,Aldi GmbH & Co. KG,Aldi Eink ...

# %% [markdown]
# ### Use marker-color to encode further information
# In order to map feature values to marker-colors, *Bokeh* provides
# * different types of [Color Mappers](https://bokeh.pydata.org/en/latest/docs/reference/models/mappers.html#). As the name suggests, a color mapper maps a value of a categorical or a numeric variable into a color of a specified color pallete.
# * a bunch of [Color Palettes](https://bokeh.pydata.org/en/latest/docs/reference/palettes.html).
#
# In the code-cells below the `LinearColorMapper` and the `viridis` color-pallete is applied. For the ColorMapper the color-pallete and the minimum- and maximum-value of the variable's value range must be defined. For the color-pallete the number of different colors must be defined (20 in the example below). In the `circle()`-method, the a dictionary must be assigned to the `color`-argument,
#
# ```color={'field': 'fat_100g', 'transform': mapper},```
#
# which defines
# * the dataframe-column for which values shall be mapped to color
# * the color-mapper object to be used.
#
#
# In order to understand which values are mapped to which colors a corresponding [ColorBar](https://bokeh.pydata.org/en/latest/docs/reference/models/annotations.html) can be added to the layout, as shown below:

# %%
#import modules for color - mapping:
from bokeh.palettes import magma,viridis
from bokeh.models.mappers import LinearColorMapper
from bokeh.models import ColumnDataSource,HoverTool, ColorBar

# %%
#create Color-Mapper object with specified color-pallete
mapper=LinearColorMapper(palette=viridis(20),low=germanFood["fat_100g"].min(),high=germanFood["fat_100g"].max())

# %%
#create ColorBar object
color_bar = ColorBar(color_mapper=mapper, location=(0, 0))

# %%
hover = HoverTool(tooltips = [("Productname","@product_name"),("Brand","@brands")], mode="mouse") #other modes: vline, hline
options = dict(plot_width=800, plot_height=500,
               tools=[hover,"crosshair,pan,wheel_zoom,box_zoom,box_select,lasso_select,reset"])

p = figure(title="Proteins vs. Carbohydrates", x_axis_label="carbohydrates/100g", y_axis_label="proteins/100g", **options)
p.circle("carbohydrates_100g","proteins_100g", size="normedEnergy", color={'field': 'fat_100g', 'transform': mapper}, alpha=0.8, source=source)
p.add_layout(color_bar, 'left')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b048cfba-eef2-4e7e-83d6-3802516f69be"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("b048cfba-eef2-4e7e-83d6-3802516f69be");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b048cfba-eef2-4e7e-83d6-3802516f69be");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b048cfba-eef2-4e7e-83d6-3802516f69be' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"47d3ea22-e8c5-4412-ac24-67db37a04e59":{"roots":{"references":[{"attributes":{"plot":{"id":"5a7c3e36-125b-4e34-90db-0a08e4e123db","subtype":"Figure","type":"Plot"}},"id":"1f817e9f-e6e4-4a7e-952b-933584639610","type":"ResetTool"},{"attributes":{"callback":null,"overlay":{"id":"8f3ea9b0-944d-4e65-b23e-7c470f9df360","type":"PolyAnnotation"},"plot":{"id":"5a7c3e36-125b-4e34-90db-0a08e4e123db","subtype":"Figure","type":"Plot"}},"id":"0025a849-c3b3-4235-ad99-f5ad05459aa9","type":"LassoSelectTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"14170a0e-81d9-437f-abaa-99c373989ea0","type":"BoxAnnotation"},{"attributes":{"fill_alpha":{"value":0.8},"fill_color":{"field":"fat_100g","transform":{"id":"f811c13d-b3f1-4181-97c5-f262e203663c","type":"LinearColorMapper"}},"line_alpha":{"value":0.8},"line_color":{"field":"fat_100g","transform":{"id":"f811c13d-b3f1-4181-97c5-f262e203663c","type":"LinearColorMapper"}},"size":{"field":"normedEnergy","units":"screen"},"x":{"field":"carbohydrates_100g"},"y":{"field":"proteins_100g"}},"id":"71463677-544c-44c6-926c-3077bb6df8f0","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"xs_units":"screen","ys_units":"screen"},"id":"8f3ea9b0-944d-4e65-b23e-7c470f9df360","type":"PolyAnnotation"},{"attributes":{},"id":"2036c2f4-583b-477e-aa31-40d6b3557068","type":"BasicTickFormatter"},{"attributes":{"callback":null,"overlay":{"id":"14170a0e-81d9-437f-abaa-99c373989ea0","type":"BoxAnnotation"},"plot":{"id":"5a7c3e36-125b-4e34-90db-0a08e4e123db","subtype":"Figure","type":"Plot"},"renderers":[{"id":"ce997f28-1e73-44cc-bae3-68e3873f2deb","type":"GlyphRenderer"}]},"id":"51d7b242-386f-4567-a815-ceb979d636c5","type":"BoxSelectTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"61e5c044-1d3f-4f64-b861-653e1e3b9306","type":"BoxAnnotation"},{"attributes":{},"id":"c3cc4e01-1f03-4a15-8b88-92c9d8eee14a","type":"BasicTickFormatter"},{"attributes":{"color_mapper":{"id":"f811c13d-b3f1-4181-97c5-f262e203663c","type":"LinearColorMapper"},"formatter":{"id":"c3cc4e01-1f03-4a15-8b88-92c9d8eee14a","type":"BasicTickFormatter"},"location":[0,0],"plot":{"id":"5a7c3e36-125b-4e34-90db-0a08e4e123db","subtype":"Figure","type":"Plot"},"ticker":{"id":"e7cb13dc-bfc0-4f01-a6ff-457d666fb23c","type":"BasicTicker"}},"id":"9e7d9d50-e646-409b-9fd2-022cc4509dd2","type":"ColorBar"},{"attributes":{},"id":"b2b8768b-d211-48ef-9ad8-c308a697c1a9","type":"BasicTicker"},{"attributes":{"plot":{"id":"5a7c3e36-125b-4e34-90db-0a08e4e123db","subtype":"Figure","type":"Plot"}},"id":"16caa126-01eb-43d9-8a0a-3f0768029a5c","type":"PanTool"},{"attributes":{"callback":null,"column_names":["brands","product_name","main_category","energy_100g","fat_100g","proteins_100g","salt_100g","carbohydrates_100g","sugars_100g","sodium_100g","saturated-fat_100g","normedEnergy","index"],"data":{"brands":["Candy Crush","Candy Crush","Del Monte","The Invisible Chef","The Invisible Chef","vitasia","Sun Snacks (Aldi S\u00fcd)","Bergader","Ikea","Freihofer Gourmet,Aldi Einkauf GmbH & Co. oHG","Moser-Roth,Aldi GmbH & Co. KG,Aldi Einkauf GmbH & Co. oHG","Moser-Roth,Aldi GmbH & Co. KG,Aldi Einkauf GmbH & Co. oHG","Scholetta,Aldi Einkauf GmbH & Co. oHG","Milbona","Combino","Freshona, Fresh & Easy","N\u00fcrnberger-Wein-Kellerei","Fin Carr\u00e9, ...

# %% [markdown]
# ## Linking of Plots
# Sometimes one dataset is visualized in multiple plots, each providing a different perspective on or different features of the given dataset. In this case a linking of the related plots may be advantageous. With linking one or more data points can be selected in one plot and they get highlighted in all joint plots.
#
# For displaying multiple joint plots usually Bokeh's `gridplot()`-method is applied and the joint plots all apply the same *data source* of type `ColumnDataSource`:

# %%
from bokeh.layouts import gridplot
source = ColumnDataSource(germanFood)

options = dict(plot_width=500, plot_height=500,
               tools="pan,wheel_zoom,box_zoom,box_select,lasso_select,reset")

p1 = figure(title="energy vs fat", **options)
p1.circle("fat_100g","energy_100g", color="blue", size=6, source=source)

p2 = figure(title="energy vs protein",y_range=p1.y_range, **options)
p2.diamond("proteins_100g","energy_100g", color="green", size=6, source=source)
#p3.circle("proteins_100g","energy_100g", size="sugars_100g", fill_color="fat_100g", source=source)

p3 = figure(title="energy vs sugar",y_range=p1.y_range, **options)
p3.square("sugars_100g","energy_100g", color="red", size=6, source=source)

p4 = figure(title="energy vs carbohydrates",y_range=p1.y_range, **options)
p4.triangle("carbohydrates_100g","energy_100g",color="orange", size=6, source=source)

p = gridplot([[ p1, p2],[ p3, p4]], toolbar_location="right")

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="8fb1e1d3-7581-42ec-b5d8-ffbb01076f27"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("8fb1e1d3-7581-42ec-b5d8-ffbb01076f27");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8fb1e1d3-7581-42ec-b5d8-ffbb01076f27");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8fb1e1d3-7581-42ec-b5d8-ffbb01076f27' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f2a3fa99-2d02-4768-af5d-e032a2847d96":{"roots":{"references":[{"attributes":{},"id":"340a1bb1-b519-4547-9403-ba69e2262a5c","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"340a1bb1-b519-4547-9403-ba69e2262a5c","type":"BasicTickFormatter"},"plot":{"id":"a4fa26da-d48d-4ba4-a5b6-d1d5a7495d35","subtype":"Figure","type":"Plot"},"ticker":{"id":"3247cfa3-5179-4394-9114-a8bab6cede17","type":"BasicTicker"}},"id":"b62a7718-83a4-4bdb-9d62-f4733446cd69","type":"LinearAxis"},{"attributes":{},"id":"3247cfa3-5179-4394-9114-a8bab6cede17","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"a4fa26da-d48d-4ba4-a5b6-d1d5a7495d35","subtype":"Figure","type":"Plot"},"ticker":{"id":"3247cfa3-5179-4394-9114-a8bab6cede17","type":"BasicTicker"}},"id":"ff90d3e6-0fb3-4a35-b4c3-e188874a8124","type":"Grid"},{"attributes":{"fill_color":{"value":"red"},"line_color":{"value":"red"},"size":{"units":"screen","value":6},"x":{"field":"sugars_100g"},"y":{"field":"energy_100g"}},"id":"7815dcb0-9eea-4121-a533-5349fec9d073","type":"Square"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"8a9d21c0-d2c5-4ef7-a5ca-f5cfac6bb6cd","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"a4fa26da-d48d-4ba4-a5b6-d1d5a7495d35","subtype":"Figure","type":"Plot"}},"id":"0244ee9b-6286-4ff1-860b-971aaef1dab3","type":"PanTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":6},"x":{"field":"sugars_100g"},"y":{"field":"energy_100g"}},"id":"85ba1087-bcd4-4117-ab16-57ee8ced8ca6","type":"Square"},{"attributes":{"plot":{"id":"a4fa26da-d48d-4ba4-a5b6-d1d5a7495d35","subtype":"Figure","type":"Plot"}},"id":"9347b145-735d-4615-8db0-408fa342166f","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"8a9d21c0-d2c5-4ef7-a5ca-f5cfac6bb6cd","type":"BoxAnnotation"},"plot":{"id":"a4fa26da-d48d-4ba4-a5b6-d1d5a7495d35","subtype":"Figure","type":"Plot"}},"id":"bf843d42-aaad-41ec-8437-df5fcc2e7087","type":"BoxZoomTool"},{"attributes":{"callback":null,"overlay":{"id":"65decbb2-85b0-42ff-8371-0b13bf91942b","type":"BoxAnnotation"},"plot":{"id":"a4fa26da-d48d-4ba4-a5b6-d1d5a7495d35","subtype":"Figure","type":"Plot"},"renderers":[{"id":"b1e62112-cabe-4676-9403-71838a2f1b73","type":"GlyphRenderer"}]},"id":"d0db4f96-8e0d-43c0-9649-2340407a0eef","type":"BoxSelectTool"},{"attributes":{"callback":null,"overlay":{"id":"bf8dde85-5220-476c-ba5e-6115e3d68bb3","type":"PolyAnnotation"},"plot":{"id":"a4fa26da-d48d-4ba4-a5b6-d1d5a7495d35","subtype":"Figure","type":"Plot"}},"id":"ac5af8c2-42ab-48c6-b2be-815cbcd03740","type":"LassoSelectTool"},{"attributes":{"plot":{"id":"a4fa26da-d48d-4ba4-a5b6-d1d5a7495d35","subtype":"Figure","type":"Plot"}},"id":"48c719e1-bd6e-4575-86a3-9c20694fb878","type":"ResetTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"65decbb2-85b0-42ff-8371-0b13bf91942b","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"aa5b42cd-3f3d-470f-a657-8ff7ef5f5b7b","subtype":"Figure","type":"Plot"}},"id":"aaa7520c-c976-4852-aa76-580252400642","type":"WheelZoomTool"},{"attributes":{"data_source":{"id":"572c5f84-2215-4d73-a44b-3b6050f8fad2","type":"ColumnDataSource"},"glyph":{"id":"7815dcb0-9eea-4121-a533-5349fec9d073","type":"Square"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"85ba1087-bcd4-4117-ab16-57ee8ced8ca6","type":"Square"},"selection_glyph":null},"id":"b1e62112-c ...

# %% [markdown]
# In the plots above different marker-symbols have been applied. There exist much more markers and other chart-types, that can be used to draw data. See for example [Bokeh, Plotting with basic glyphs](http://bokeh.pydata.org/en/latest/docs/user_guide/plotting.html#userguide-plotting) or [bokeh.plotting reference](https://bokeh.pydata.org/en/latest/docs/reference/plotting.html). Some of the most frequently applied chart-types are demonstrated in the following section.

# %% [markdown]
# ## Other plot types
# ### Bar Plots
# Bar plots are frequently applied, e.g. for the viusalisations of value-frequencies (histograms). For example, in the food-dataset, used in this notebook, one may be interested in the frequency of each category (column `main_category` in the dataframe). For this we first apply the *Pandas*-method `groupby()` for summarizing all products by their `main_category`. Then for all categories with more than one product, a histogram is plotted:

# %%
categoryCount=germanFood.groupby(by="main_category")["brands"].count()

# %%
cats=categoryCount[categoryCount>1]

# %%
px = figure(title="Categories with more than one product",x_range=cats.index.tolist(),plot_width=700)
px.vbar(cats.index.tolist(),bottom=0,top=cats.values.tolist(),color="blue",width=0.8,alpha=0.6)
px.xaxis.major_label_orientation = "vertical"
show(px)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="56b5306a-662a-4d86-bf4a-50237457b5c4"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("56b5306a-662a-4d86-bf4a-50237457b5c4");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("56b5306a-662a-4d86-bf4a-50237457b5c4");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '56b5306a-662a-4d86-bf4a-50237457b5c4' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"826fecdd-0aad-4f63-a71e-bf53e917c635":{"roots":{"references":[{"attributes":{},"id":"155fae02-666d-4b46-98d8-003d28edab53","type":"BasicTicker"},{"attributes":{"formatter":{"id":"e347d4b1-d4dd-44f8-90b4-9aebedf18403","type":"CategoricalTickFormatter"},"major_label_orientation":"vertical","plot":{"id":"f78508ef-01c3-4c28-9231-5a322eb4ee36","subtype":"Figure","type":"Plot"},"ticker":{"id":"53fa2c0d-b9f6-4ea7-9de0-53221356d416","type":"CategoricalTicker"}},"id":"448847ab-dfd7-428d-9402-a550a66d6109","type":"CategoricalAxis"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"top":{"field":"top"},"width":{"value":0.8},"x":{"field":"x"}},"id":"dfb93c38-24f2-43f9-af59-043e16a046ea","type":"VBar"},{"attributes":{"data_source":{"id":"cae38543-008d-4d20-821f-ab03265f9ce5","type":"ColumnDataSource"},"glyph":{"id":"b22ea9e4-69e4-4aae-9775-a15a6bbd8fbf","type":"VBar"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"dfb93c38-24f2-43f9-af59-043e16a046ea","type":"VBar"},"selection_glyph":null},"id":"15a7ef8e-6ad5-47b0-8b93-76db618ac456","type":"GlyphRenderer"},{"attributes":{"formatter":{"id":"90448ce1-e672-436d-8096-45caea79d6b7","type":"BasicTickFormatter"},"plot":{"id":"f78508ef-01c3-4c28-9231-5a322eb4ee36","subtype":"Figure","type":"Plot"},"ticker":{"id":"155fae02-666d-4b46-98d8-003d28edab53","type":"BasicTicker"}},"id":"8dcc6f62-6d23-4e9d-9fac-5af812e33b47","type":"LinearAxis"},{"attributes":{"callback":null},"id":"c973e5fa-a096-4bd7-ba3b-965e31682c74","type":"DataRange1d"},{"attributes":{"plot":{"id":"f78508ef-01c3-4c28-9231-5a322eb4ee36","subtype":"Figure","type":"Plot"}},"id":"38d58316-58fa-4077-8519-8532f16bded3","type":"WheelZoomTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"66074658-f893-4592-bfd7-66291b2277dc","type":"PanTool"},{"id":"38d58316-58fa-4077-8519-8532f16bded3","type":"WheelZoomTool"},{"id":"0ef8cc30-ae97-46ec-bfe2-88a6f5a6c144","type":"BoxZoomTool"},{"id":"b70d60a7-ddcb-4384-90e8-f823cf048e71","type":"SaveTool"},{"id":"0b8aacd1-cb47-45bf-9faa-a636aa8b8c89","type":"ResetTool"},{"id":"36a8fdf7-b1f8-45e4-959a-1f69ea681b0c","type":"HelpTool"}]},"id":"04d10ef3-e7f1-4bd9-9733-08ec96c99c12","type":"Toolbar"},{"attributes":{"below":[{"id":"448847ab-dfd7-428d-9402-a550a66d6109","type":"CategoricalAxis"}],"left":[{"id":"8dcc6f62-6d23-4e9d-9fac-5af812e33b47","type":"LinearAxis"}],"plot_width":700,"renderers":[{"id":"448847ab-dfd7-428d-9402-a550a66d6109","type":"CategoricalAxis"},{"id":"839962f8-500b-475a-9d0b-81cf9f3bc160","type":"Grid"},{"id":"8dcc6f62-6d23-4e9d-9fac-5af812e33b47","type":"LinearAxis"},{"id":"3a9a5686-fc00-45d0-96ed-6de29817f041","type":"Grid"},{"id":"66041f6e-1ded-4d0f-b389-d1619cef7511","type":"BoxAnnotation"},{"id":"15a7ef8e-6ad5-47b0-8b93-76db618ac456","type":"GlyphRenderer"}],"title":{"id":"b63961e6-012d-4029-a235-6f66851d9888","type":"Title"},"tool_events":{"id":"2bd6b26f-69e9-45e1-b229-b3961de9e50e","type":"ToolEvents"},"toolbar":{"id":"04d10ef3-e7f1-4bd9-9733-08ec96c99c12","type":"Toolbar"},"x_range":{"id":"f694f943-fa6a-4eeb-bf00-a65cbd5d1fc5","type":"FactorRange"},"y_range":{"id":"c973e5fa-a096-4bd7-ba3b-965e31682c74","type":"DataRange1d"}},"id":"f78508ef-01c3-4c28-9231-5a322eb4ee36","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"f78508ef-01c3-4c28-9231-5a322eb4ee36","subtype":"Figure","type":"Plot"}},"id":"0b8aacd1-cb47-45bf-9faa-a636aa8b8c89","type":"ResetTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"66041f6e-1ded-4d0f-b389-d1619cef7511","type":"BoxAnnotation"},{"attributes":{},"id":"2bd6b26f-69e9-45e1-b229-b3961de9e50e ...
