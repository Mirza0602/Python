# %%
import pandas as pd
#import bokeh
from IPython.display import display
from bokeh.plotting import figure 
from bokeh.io import output_notebook, show
from bokeh.models import ColumnDataSource
from bokeh.layouts import gridplot

# %%
dfclean.to_csv("germanProductSubset.csv",encoding="utf-8")

# %%
germanFood=pd.read_csv("germanProductSubset.csv",index_col=0)

# %%
display(germanFood.head())
print(germanFood.shape)
# Out:
#                brands                          product_name  \
# 0         Candy Crush                    Sour Fruit Gummies
# 1         Candy Crush                            Jelly Fish
# 2           Del Monte             Ananas Scheiben gezuckert
# 4  The Invisible Chef  Pancake & Waffle Mix Lemon Blueberry
# 8  The Invisible Chef       Pancake & Waffle Mix Buttermilk
#
#                         main_category  energy_100g  fat_100g  proteins_100g  \
# 0                    en:sugary-snacks       1360.0       0.0            5.0
# 1                    en:sugary-snacks        586.0       0.0            0.0
# 2  en:plant-based-foods-and-beverages        322.0       0.0            0.0
# 4                      en:pancake-mix        852.0       1.0            6.0
# 8                      en:pancake-mix        962.0       0.0            7.0
#
#    salt_100g  carbohydrates_100g  sugars_100g  sodium_100g  saturated-fat_100g
# ...

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="cbe8ef60-3d8b-4d1e-b5b5-47565439863e">Loading BokehJS ...</span>
#     </div>

# %%
source = ColumnDataSource(germanFood)

options = dict(plot_width=500, plot_height=500,
               tools="pan,wheel_zoom,box_zoom,box_select,lasso_select,reset")

p1 = figure(title="energy vs fat", **options)
p1.circle("fat_100g","energy_100g", color="blue", source=source)

p2 = figure(title="energy vs sugar", **options)
p2.circle("sugars_100g","energy_100g", color="green", source=source)

p3 = figure(title="energy vs protein", **options)
p3.circle("proteins_100g","energy_100g", source=source)
#p3.circle("proteins_100g","energy_100g", size="sugars_100g", fill_color="fat_100g", source=source)

p4 = figure(title="energy vs salt", **options)
p4.circle("salt_100g","energy_100g", source=source)

p = gridplot([[ p1, p2],[ p3, p4]], toolbar_location="right")

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="6b93ef85-6c5f-4cfc-b351-58dca27884d4"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %%
options = dict(plot_width=800, plot_height=500,x_range=[-1,90],y_range=[-1,110],
               tools="crosshair,pan,wheel_zoom,box_zoom,box_select,lasso_select,reset")
colors = [
    "#%02x%02x%02x" % (int(r), int(g), 150) for r, g in zip(50+2*germanFood["proteins_100g"], 30+2*germanFood["carbohydrates_100g"])
]
p = figure(title="energy vs fat", x_axis_label='proteins', y_axis_label='carb',**options)

p.circle(germanFood["proteins_100g"],germanFood["carbohydrates_100g"],radius=0.7, fill_color=colors, fill_alpha=0.6, line_color=None)
#p3.circle("proteins_100g","energy_100g", size="sugars_100g", fill_color="fat_100g", source=source)
#p.circle(x, y, size=7, color="firebrick", alpha=0.5)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="4eeb552f-f392-427a-aba3-377f3256a3d3"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...
