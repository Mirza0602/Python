# %% [markdown]
# # Interactive Plotting with Bokeh
# * Author: Johannes Maucher
# * Last update: 03.05.2018

# %%
import pandas as pd
#import bokeh
from IPython.display import display
from bokeh.plotting import figure 
from bokeh.io import output_notebook, show
from bokeh.models import ColumnDataSource,HoverTool

# %%
germanFood=pd.read_csv("germanProductSubset.csv",index_col=0)

# %%
display(germanFood.head(20))
print(germanFood.shape)
# Out:
#                                                brands  \
# 0                                         Candy Crush
# 1                                         Candy Crush
# 2                                           Del Monte
# 4                                  The Invisible Chef
# 8                                  The Invisible Chef
# 11                                            vitasia
# 12                              Sun Snacks (Aldi Süd)
# 14                                           Bergader
# 15                                               Ikea
# 16      Freihofer Gourmet,Aldi Einkauf GmbH & Co. oHG
# 23  Moser-Roth,Aldi GmbH & Co. KG,Aldi Einkauf Gmb...
# 24  Moser-Roth,Aldi GmbH & Co. KG,Aldi Einkauf Gmb...
# 25              Scholetta,Aldi Einkauf GmbH & Co. oHG
# 30                                            Milbona
# 31                                            Combino
# 32                             Freshona, Fresh & Easy
# 33                           Nürnberger-Wein-Kellerei
# 34  Fin Carré,Lidl Stiftung & Co. KG,Schwarz Betei...
# 35                            Saint Alby,Gebirgsjäger
# 36                                      Envia,Milbona
#
#                                          product_name  \
# 0                                  Sour Fruit Gummies
# 1                                          Jelly Fish
# 2                           Ananas Scheiben gezuckert
# 4                Pancake & Waffle Mix Lemon Blueberry
# 8                     Pancake & Waffle Mix Buttermilk
# 11                    Thai Noodles sweet & sour sauce
# 12                                        Salzstangen
# 14                                           Edelpilz
# 15                                     Rye crispbread
# 16           Edelbitterschokolade Sao Thomé 75% Kakao
# 23         Edel-Zartbitterschokolade Minze 52 % Kakao
# 24         Edel-Zartbitterschokolade Chili 52 % Kakao
# 25  Zarbitter Schokolade mit gerösteten Mandelstüc...
# 30                                        Schlagsahne
# 31                            Sauce tomate bolognaise
# 32                                         Cornichons
# 33                               Christkindl Glühwein
# 34                           Dark chocolate 50% cocoa
# 35                                          Bockwurst
# 36                              Crème Entière liquide
#
#                          main_category  energy_100g  fat_100g  proteins_100g  \
# 0                     en:sugary-snacks       1360.0       0.0            5.0
# 1                     en:sugary-snacks        586.0       0.0            0.0
# 2   en:plant-based-foods-and-beverages        322.0       0.0            0.0
# 4                       en:pancake-mix        852.0       1.0            6.0
# 8                       en:pancake-mix        962.0       0.0            7.0
# 11  en:plant-based-foods-and-beverages        617.0       2.6            3.9
# 12                     en:salty-snacks       1583.0       4.2           11.0
# 14                          en:dairies       1376.0      28.0           19.5
# 15  en:plant-based-foods-and-beverages       1463.0       2.6            9.0
# 16                    en:sugary-snacks       2314.0      42.5            9.0
# 23                    en:sugary-snacks       2284.0      34.5            4.5
# 24                    en:sugary-snacks       2275.0      34.4            4.5
# 25                    en:sugary-snacks       2307.0      37.0            7.1
# 30                          en:dairies       1207.0      30.0            2.5
# 31                        en:groceries        352.0       4.3            3.9
# 32                          en:pickles        148.0       0.3            1.2
# 33                         en:gluhwein        365.5       0.1            0.1
# 34                    en:sugary-snacks       2180.0      31.8            5.4
# 35                            en:meats       1165.0      25.0           12.0
# 36                          en:dairies       1209.0      30.0            2.4
#
#     salt_100g  carbohydrates_100g  sugars_100g  sodium_100g  \
# 0     0.12700               75.00        57.50     0.050000
# 1     0.07620               34.00        24.00     0.030000
# 2     0.02286               19.66        17.95     0.009000
# 4     1.33000               42.00         8.00     0.523622
# 8     1.57000               49.00        13.00     0.618110
# 11    0.75000               26.30         7.00     0.295276
# 12    6.70000               71.00         2.30     2.637795
# 14    3.50000                0.50         0.30     1.377953
# 15    1.20000               64.00         1.30     0.472441
# 16    0.02540               27.60        21.90     0.010000
# 23    0.01000               51.50        48.30     0.003937
# 24    0.01000               51.40        48.20     0.003937
# 25    0.01000               44.10        39.90     0.003937
# 30    0.08000                3.20         3.20     0.031496
# 31    1.40000                6.80         5.10     0.551181
# 32    1.23000                5.50         5.40     0.484252
# 33    0.10000                8.60         8.60     0.039370
# 34    0.01000               49.60        47.10     0.003937
# 35    1.94000                2.00         1.00     0.763780
# 36    0.08000                3.40         3.40     0.031496
#
#     saturated-fat_100g
# 0                  0.0
# 1                  0.0
# 2                  0.0
# 4                  0.0
# 8                  0.0
# 11                 0.6
# 12                 1.6
# 14                19.3
# 15                 0.6
# 16                26.6
# 23                20.9
# 24                20.9
# 25                19.3
# 30                20.0
# 31                 1.8
# 32                 0.1
# 33                 0.1
# 34                19.1
# 35                 9.9
# 36                21.0
# (466, 11)

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="f545276c-350b-4f67-8597-ef79dfdf49b7">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Simple 2D-Plot with interactive tools

# %%
source = ColumnDataSource(germanFood)
options = dict(plot_width=800, plot_height=500,
               tools="pan,wheel_zoom,box_zoom,box_select,lasso_select,reset")

p = figure(title="carbohydrates vs. sugar", x_axis_label="carbohydrates/100g", y_axis_label="sugars/100g", **options)
p.circle("carbohydrates_100g","sugars_100g", color="blue", size=8, alpha=0.4, source=source)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ae635e9a-37ff-4903-b8d2-6c8b5c03223d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("ae635e9a-37ff-4903-b8d2-6c8b5c03223d");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ae635e9a-37ff-4903-b8d2-6c8b5c03223d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ae635e9a-37ff-4903-b8d2-6c8b5c03223d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"6c91d400-809d-48e7-8003-7055c6b8dcbe":{"roots":{"references":[{"attributes":{"plot":{"id":"7cd6d6f0-c086-435b-8052-c70b90382415","subtype":"Figure","type":"Plot"},"ticker":{"id":"0d398a22-af4d-4cb0-8e11-611e9d3ef1e3","type":"BasicTicker"}},"id":"f4f87b99-532e-457d-a2db-d79d873f02a4","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"dd823083-301b-4ba8-9c16-eaa608723e41","type":"BoxAnnotation"},{"attributes":{},"id":"e7dd72f0-142c-4098-98ea-f3bef3738da5","type":"LinearScale"},{"attributes":{},"id":"c9078221-ee41-43de-bb10-f22d4cd4ffd2","type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":"dd823083-301b-4ba8-9c16-eaa608723e41","type":"BoxAnnotation"}},"id":"552d6fed-1d62-4848-9c43-7bbe65758ad2","type":"BoxZoomTool"},{"attributes":{"callback":null},"id":"9f321499-242e-455f-a583-96843f1fa630","type":"DataRange1d"},{"attributes":{"dimension":1,"plot":{"id":"7cd6d6f0-c086-435b-8052-c70b90382415","subtype":"Figure","type":"Plot"},"ticker":{"id":"2999195f-cd42-4c13-9303-be24d56d0d24","type":"BasicTicker"}},"id":"d727dcf5-c183-4774-bae3-e92321a431b1","type":"Grid"},{"attributes":{},"id":"17551ff3-bb67-488f-af1b-f0d930a18e45","type":"LinearScale"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"fe6da854-ff8d-432b-b531-c91c5c00ea2b","type":"PanTool"},{"id":"1fab8d1e-85cd-4976-ad16-c39ebbe03eac","type":"WheelZoomTool"},{"id":"552d6fed-1d62-4848-9c43-7bbe65758ad2","type":"BoxZoomTool"},{"id":"c5d1eff4-9ed5-4222-b4bc-9f3a833aec3a","type":"BoxSelectTool"},{"id":"16d0f7fb-327a-4227-9d19-bfc6affcfc58","type":"LassoSelectTool"},{"id":"294d5bac-a09e-42d1-b0c9-1da60c02c8df","type":"ResetTool"}]},"id":"007c7ed9-2f92-4d9c-b4a6-f7848867621f","type":"Toolbar"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"xs_units":"screen","ys_units":"screen"},"id":"0a22c94f-ccdc-4104-8b5a-ab180d5a67f1","type":"PolyAnnotation"},{"attributes":{"callback":null,"overlay":{"id":"0a22c94f-ccdc-4104-8b5a-ab180d5a67f1","type":"PolyAnnotation"}},"id":"16d0f7fb-327a-4227-9d19-bfc6affcfc58","type":"LassoSelectTool"},{"attributes":{"axis_label":"sugars/100g","formatter":{"id":"2a327ebf-e4b0-4ad6-838e-1c9ae8e126e4","type":"BasicTickFormatter"},"plot":{"id":"7cd6d6f0-c086-435b-8052-c70b90382415","subtype":"Figure","type":"Plot"},"ticker":{"id":"2999195f-cd42-4c13-9303-be24d56d0d24","type":"BasicTicker"}},"id":"dec84881-8dd7-4fea-8edf-2516100a18bd","type":"LinearAxis"},{"attributes":{"below":[{"id":"62bb37fc-a1e3-488f-8f1a-4809d28f8f09","type":"LinearAxis"}],"left":[{"id":"dec84881-8dd7-4fea-8edf-2516100a18bd","type":"LinearAxis"}],"plot_height":500,"plot_width":800,"renderers":[{"id":"62bb37fc-a1e3-488f-8f1a-4809d28f8f09","type":"LinearAxis"},{"id":"f4f87b99-532e-457d-a2db-d79d873f02a4","type":"Grid"},{"id":"dec84881-8dd7-4fea-8edf-2516100a18bd","type":"LinearAxis"},{"id":"d727dcf5-c183-4774-bae3-e92321a431b1","type":"Grid"},{"id":"dd823083-301b-4ba8-9c16-eaa608723e41","type":"BoxAnnotation"},{"id":"68d885d1-6743-44b3-85a8-a0c15755198e","type":"BoxAnnotation"},{"id":"0a22c94f-ccdc-4104-8b5a-ab180d5a67f1","type":"PolyAnnotation"},{"id":"25449f65-2982-4571-bc78-19205106e818","type":"GlyphRenderer"}],"title":{"id":"4b698f61-afb3-4696-89b4-48755ceac943","type":"Title"},"toolbar":{"id":"007c7ed9-2f92-4d9c-b4a6-f7848867621f","type":"Toolbar"},"x_range":{"id":"525a19fc-045d-4355-8f6c-300c45af65b6","type":"DataRange1d"},"x_scale":{"id":"17551ff3-bb67-488f-af1b-f0d930a18e45","type":"LinearScale"},"y_range":{"id":"9f321499-242e-455f-a583-9 ...

# %% [markdown]
# **Conclusions from the plot above:**
# * sugar is a form of carbohydrate, but not the only one

# %%
p = figure(title="Proteins vs. Carbohydrates", x_axis_label="carbohydrates/100g", y_axis_label="proteins/100g", **options)
p.circle("carbohydrates_100g","proteins_100g", color="blue", size=8, alpha=0.4, source=source)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="091c2bea-d623-41f5-ab14-e7b23f8f1489"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("091c2bea-d623-41f5-ab14-e7b23f8f1489");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("091c2bea-d623-41f5-ab14-e7b23f8f1489");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '091c2bea-d623-41f5-ab14-e7b23f8f1489' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"31cdf5b0-9160-4e1e-8255-9669188bc138":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"e02f531f-9360-4626-803f-a100f9e189b3","type":"BoxAnnotation"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"54e130d5-00d1-42f1-99be-093ec3d42f6b","type":"BoxAnnotation"},{"attributes":{"plot":null,"text":"Proteins vs. Carbohydrates"},"id":"42a2d208-2b2b-4101-9e6b-486e1720c3b1","type":"Title"},{"attributes":{"axis_label":"carbohydrates/100g","formatter":{"id":"8f3093fe-a037-4b46-a47f-52101c48a9fb","type":"BasicTickFormatter"},"plot":{"id":"e1c59362-d141-443d-8319-278703c579a0","subtype":"Figure","type":"Plot"},"ticker":{"id":"59e463a4-2a2b-4505-81ea-2bbddab25f2c","type":"BasicTicker"}},"id":"7cc75361-e6f2-436f-955f-7c342ace1cac","type":"LinearAxis"},{"attributes":{"fill_alpha":{"value":0.4},"fill_color":{"value":"blue"},"line_alpha":{"value":0.4},"line_color":{"value":"blue"},"size":{"units":"screen","value":8},"x":{"field":"carbohydrates_100g"},"y":{"field":"proteins_100g"}},"id":"d6082731-195a-467f-977e-9d78b67be64c","type":"Circle"},{"attributes":{"data_source":{"id":"24b84432-091a-4607-9e6f-4650e3f0ceba","type":"ColumnDataSource"},"glyph":{"id":"d6082731-195a-467f-977e-9d78b67be64c","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"4a7fc3d8-fa41-4398-a076-1871e1f941e0","type":"Circle"},"selection_glyph":null,"view":{"id":"8b5be5da-12f2-4ba2-b4fc-f65a2662ed6d","type":"CDSView"}},"id":"56a09f25-c881-421a-a6f9-040b00adb54f","type":"GlyphRenderer"},{"attributes":{},"id":"d41a6f8a-6716-48cc-8277-e47f3f247d34","type":"PanTool"},{"attributes":{"below":[{"id":"7cc75361-e6f2-436f-955f-7c342ace1cac","type":"LinearAxis"}],"left":[{"id":"d8b48327-5030-4cd3-a5d2-51303481f67f","type":"LinearAxis"}],"plot_height":500,"plot_width":800,"renderers":[{"id":"7cc75361-e6f2-436f-955f-7c342ace1cac","type":"LinearAxis"},{"id":"3ceb26a8-ed7f-4c82-ba36-3d6ad84ba086","type":"Grid"},{"id":"d8b48327-5030-4cd3-a5d2-51303481f67f","type":"LinearAxis"},{"id":"ddb6026b-a856-4cfe-aaf8-00edf5db7ccf","type":"Grid"},{"id":"e02f531f-9360-4626-803f-a100f9e189b3","type":"BoxAnnotation"},{"id":"54e130d5-00d1-42f1-99be-093ec3d42f6b","type":"BoxAnnotation"},{"id":"f18d1ec4-c849-4bcf-8142-1a5a5a61c40f","type":"PolyAnnotation"},{"id":"56a09f25-c881-421a-a6f9-040b00adb54f","type":"GlyphRenderer"}],"title":{"id":"42a2d208-2b2b-4101-9e6b-486e1720c3b1","type":"Title"},"toolbar":{"id":"aec57b0f-6a13-470b-9410-f4953c19ac96","type":"Toolbar"},"x_range":{"id":"e48b31f8-ea08-4b2f-b002-0d8bc2e68638","type":"DataRange1d"},"x_scale":{"id":"c62b4ad1-1642-4635-af19-ed55c9e54df9","type":"LinearScale"},"y_range":{"id":"43a72fe3-8fb4-4133-89ab-c73e2099fd9d","type":"DataRange1d"},"y_scale":{"id":"c25351ec-e2e2-4527-a436-7aa771d40d48","type":"LinearScale"}},"id":"e1c59362-d141-443d-8319-278703c579a0","subtype":"Figure","type":"Plot"},{"attributes":{"source":{"id":"24b84432-091a-4607-9e6f-4650e3f0ceba","type":"ColumnDataSource"}},"id":"8b5be5da-12f2-4ba2-b4fc-f65a2662ed6d","type":"CDSView"},{"attributes":{},"id":"c62b4ad1-1642-4635-af19-ed55c9e54df9","type":"LinearScale"},{"attributes":{},"id":"59e463a4-2a2b-4505-81ea-2bbddab25f2c","type":"BasicTicker"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"xs_units":"scre ...

# %% [markdown]
# **Improvements:**
# * For a given point, we want to
#     * determine the coordinates more accurately
#     * know the name of the corresponding product

# %%
hover = HoverTool(tooltips = [("Productname","@product_name"),("Brand","@brands")], mode="mouse") #other modes: vline, hline
options = dict(plot_width=800, plot_height=500,
               tools=[hover,"crosshair,pan,wheel_zoom,box_zoom,box_select,lasso_select,reset"])

p = figure(title="Proteins vs. Carbohydrates", x_axis_label="carbohydrates/100g", y_axis_label="proteins/100g", **options)
p.circle("carbohydrates_100g","proteins_100g", color="blue", size=8, alpha=0.4, source=source)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="302ed624-5ac9-48f6-9838-0c0b244eb340"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("302ed624-5ac9-48f6-9838-0c0b244eb340");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("302ed624-5ac9-48f6-9838-0c0b244eb340");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '302ed624-5ac9-48f6-9838-0c0b244eb340' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"ebb824fe-f8b6-4dae-aee9-6d57ca5ce597":{"roots":{"references":[{"attributes":{},"id":"87f5aa52-13ea-4141-b5be-60c0d440e997","type":"LinearScale"},{"attributes":{},"id":"75afaa51-7950-43a0-8a29-493bae840a94","type":"LinearScale"},{"attributes":{},"id":"a05c4dce-8316-4df9-a990-207f3b437e6a","type":"WheelZoomTool"},{"attributes":{"callback":null,"overlay":{"id":"41035f5a-b243-4daf-b68d-676fe3065735","type":"BoxAnnotation"},"renderers":[{"id":"e1709ec9-5d78-4134-9a2e-b34d6c3f6f92","type":"GlyphRenderer"}]},"id":"5d532d63-5067-45d9-a8a4-8e7661fc8b75","type":"BoxSelectTool"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"xs_units":"screen","ys_units":"screen"},"id":"fce8573b-dc2b-407c-a9b7-c39dab209130","type":"PolyAnnotation"},{"attributes":{"source":{"id":"24b84432-091a-4607-9e6f-4650e3f0ceba","type":"ColumnDataSource"}},"id":"d69fc3f4-8e0b-4191-8338-6b5c2267b981","type":"CDSView"},{"attributes":{"callback":null},"id":"ea895094-5142-47b6-be2d-fff0f6384939","type":"DataRange1d"},{"attributes":{},"id":"75669d02-a624-4079-8608-9a9feb66b6f2","type":"BasicTickFormatter"},{"attributes":{"callback":null},"id":"6033200b-7d96-422f-b550-a4cde74bfa4f","type":"DataRange1d"},{"attributes":{},"id":"ee4af6b3-4665-4ec0-8668-51ed7487f49c","type":"CrosshairTool"},{"attributes":{"overlay":{"id":"75cf37d5-ba77-4aee-ae65-469c8376dbbf","type":"BoxAnnotation"}},"id":"d126c32c-db89-4ac4-ad3a-72bae5d41c9e","type":"BoxZoomTool"},{"attributes":{"axis_label":"carbohydrates/100g","formatter":{"id":"36215ff9-38a9-428d-90b2-cdbab0c7f380","type":"BasicTickFormatter"},"plot":{"id":"604daab7-60bf-4837-a8a6-c419ce68fb3c","subtype":"Figure","type":"Plot"},"ticker":{"id":"f01ecac4-90b0-4a23-9c3d-d2b2d9fa0403","type":"BasicTicker"}},"id":"52dc6b17-d8ca-43a4-88fb-80eedd50fe47","type":"LinearAxis"},{"attributes":{"plot":{"id":"604daab7-60bf-4837-a8a6-c419ce68fb3c","subtype":"Figure","type":"Plot"},"ticker":{"id":"f01ecac4-90b0-4a23-9c3d-d2b2d9fa0403","type":"BasicTicker"}},"id":"5655256b-f0af-445a-9d39-bcdeb4e4c7df","type":"Grid"},{"attributes":{},"id":"36215ff9-38a9-428d-90b2-cdbab0c7f380","type":"BasicTickFormatter"},{"attributes":{"dimension":1,"plot":{"id":"604daab7-60bf-4837-a8a6-c419ce68fb3c","subtype":"Figure","type":"Plot"},"ticker":{"id":"69b38891-8a6a-432c-8e14-3f43be748181","type":"BasicTicker"}},"id":"32b3afea-fb9b-40db-ac9e-2737bffab0b5","type":"Grid"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"a4de16a3-356c-495c-b0ab-c75d44410622","type":"HoverTool"},{"id":"ee4af6b3-4665-4ec0-8668-51ed7487f49c","type":"CrosshairTool"},{"id":"e7366f1c-c3ea-486e-9e51-52e339492def","type":"PanTool"},{"id":"a05c4dce-8316-4df9-a990-207f3b437e6a","type":"WheelZoomTool"},{"id":"d126c32c-db89-4ac4-ad3a-72bae5d41c9e","type":"BoxZoomTool"},{"id":"5d532d63-5067-45d9-a8a4-8e7661fc8b75","type":"BoxSelectTool"},{"id":"04dfb721-f739-414c-abea-d848b7f18111","type":"LassoSelectTool"},{"id":"bf7f8ccd-edad-4032-a4c7-e4a4863198e0","type":"ResetTool"}]},"id":"b598954d-efba-4569-997a-365de199b674","type":"Toolbar"},{"attributes":{},"id":"69b38891-8a6a-432c-8e14-3f43be748181","type":"BasicTicker"},{"attributes":{"below":[{"id":"52dc6b17-d8ca-43a4-88fb-80eedd50fe47","type":"LinearAxis"}],"left":[{"id":"d0a06aea-a82d-48a5-9b59-a7223dd9b08d","type":"LinearAxis"}],"plot_height":500,"plot_width":800,"renderers":[{"id":"52dc6b17-d8ca-43a4-88fb-80eedd50fe47","type":"LinearAxis"},{"id":"5655256b-f0af-445a-9d39-bcdeb4e4c7df","type":"Grid"},{"id":"d0a06aea-a82d-48a5-9b59-a7223dd9b08d","type":"LinearAxis"},{"id":"32b3afea-fb9b-40db-ac9e-2737bffab0b5","type":"Grid"},{"id":"75cf37d5-ba77-4aee-ae65-469c8376dbbf","type":"BoxAnnotation"},{"id":"41035f5a-b243-4daf-b68d-676fe3065735","type":"BoxAnnotation"},{"id":"fce8573b-dc2b-407c-a9b7-c39dab209130" ...

# %% [markdown]
# ## Encode further information in marker size- and color
# As demonstrated in the example above, each single point in the 2-dimensional plot encodes at least two feature-values. It's first component is the value of the first feature and the second is it's value of the second feature. Moreover, we can also annotate each point with textual information. In the example above, the `HoverTool` has been applied to display for each point two further feature-values: *product_name* and *brand*. Further information (feature values) can be visualized by the size and color of single points. This is demonstrated below, where
# * the marker-size shall encode the value of the feature `energy_100g`
# * the marker-color shall encode the value of the feature `fat_100g`
#
# ### Use marker-size to encode further information
# In order to encode the `energy_100g`-values by the marker size,
#
# 1. we scale the `energy_100g`-values into a range, which is suitable for marker sizes. This is done by first dividing all values by the maximum value. After this devision all values are $\leq 1$. Then all scaled values are multiplied by an integer, here $E=30$, which shall be the maximum marker size.
# 2. the scaled values are assigned to a new column, here `normedEnergy`, of the dataframe.
# 3. the new column `normedEnergy` is assigned to the `scale`-argument of the `circle()`-method.

# %%
import numpy as np
energy=germanFood["energy_100g"].values.astype(int)
maxEnergy=np.max(energy)
normedEnergy=energy/maxEnergy
E=30
germanFood["normedEnergy"]=E*normedEnergy
source = ColumnDataSource(germanFood)

# %%
hover = HoverTool(tooltips = [("Productname","@product_name"),("Brand","@brands")], mode="mouse") #other modes: vline, hline
options = dict(plot_width=800, plot_height=500,
               tools=[hover,"crosshair,pan,wheel_zoom,box_zoom,box_select,lasso_select,reset"])

p = figure(title="Proteins vs. Carbohydrates", x_axis_label="carbohydrates/100g", y_axis_label="proteins/100g", **options)
p.circle("carbohydrates_100g","proteins_100g", size="normedEnergy", color="blue", alpha=0.4, source=source)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0bd323de-32bf-49c4-97a5-af80e7ae1114"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("0bd323de-32bf-49c4-97a5-af80e7ae1114");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0bd323de-32bf-49c4-97a5-af80e7ae1114");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0bd323de-32bf-49c4-97a5-af80e7ae1114' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"38b53a66-71d5-4bf4-9167-a95b3e5cbfff":{"roots":{"references":[{"attributes":{"source":{"id":"94a7d435-072b-409f-a75d-3e6e1a391999","type":"ColumnDataSource"}},"id":"9c305dc6-eee7-4e00-9117-a96ad7f4d547","type":"CDSView"},{"attributes":{"below":[{"id":"e29d43e7-5250-4728-ac93-c0b665a35eb5","type":"LinearAxis"}],"left":[{"id":"0c659e43-1f17-425c-8715-0460237cdc87","type":"LinearAxis"}],"plot_height":500,"plot_width":800,"renderers":[{"id":"e29d43e7-5250-4728-ac93-c0b665a35eb5","type":"LinearAxis"},{"id":"3818e3eb-e226-44c5-92e9-9f1267252587","type":"Grid"},{"id":"0c659e43-1f17-425c-8715-0460237cdc87","type":"LinearAxis"},{"id":"96eece62-0c69-4245-8d76-6c21db1d6e5a","type":"Grid"},{"id":"e7653f57-2a83-4f27-96c7-6b2c57340cb5","type":"BoxAnnotation"},{"id":"e50e448d-6234-4265-8ed0-d3bc9ab611e2","type":"BoxAnnotation"},{"id":"e38d9009-a84c-4a77-8832-4a9465b4a447","type":"PolyAnnotation"},{"id":"c851a966-98c2-4c05-82a4-9223f1f34d33","type":"GlyphRenderer"}],"title":{"id":"3c3f6dc7-b44a-4542-80da-86c9807e85e5","type":"Title"},"toolbar":{"id":"60a9dac6-e5b4-4a99-9b38-e6e4d188ff4a","type":"Toolbar"},"x_range":{"id":"77ea7035-0df7-45d2-83c7-e6d98dd51fe4","type":"DataRange1d"},"x_scale":{"id":"2a04f53b-6313-47ec-81ae-e59854291390","type":"LinearScale"},"y_range":{"id":"f01626d9-f0ba-4c1d-9eda-5201669eb519","type":"DataRange1d"},"y_scale":{"id":"6d4a08c4-8e26-4615-9e0d-49a0417023df","type":"LinearScale"}},"id":"c16dc67f-c169-4d82-bf24-4054358e1634","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null,"column_names":["brands","product_name","main_category","energy_100g","fat_100g","proteins_100g","salt_100g","carbohydrates_100g","sugars_100g","sodium_100g","saturated-fat_100g","normedEnergy","index"],"data":{"brands":["Candy Crush","Candy Crush","Del Monte","The Invisible Chef","The Invisible Chef","vitasia","Sun Snacks (Aldi S\u00fcd)","Bergader","Ikea","Freihofer Gourmet,Aldi Einkauf GmbH & Co. oHG","Moser-Roth,Aldi GmbH & Co. KG,Aldi Einkauf GmbH & Co. oHG","Moser-Roth,Aldi GmbH & Co. KG,Aldi Einkauf GmbH & Co. oHG","Scholetta,Aldi Einkauf GmbH & Co. oHG","Milbona","Combino","Freshona, Fresh & Easy","N\u00fcrnberger-Wein-Kellerei","Fin Carr\u00e9,Lidl Stiftung & Co. KG,Schwarz Beteiligungs GmbH,Solent GmbH","Saint Alby,Gebirgsj\u00e4ger","Envia,Milbona","Alesto","eridanous,Milbona","Alesto","Naturgut,Penny","Vitasia China","Bio Sonne,Soja Food","Combino","Naturgut,Giaguaro","J.D. Gross","Crownfield,Lidl","Milbona","Gutknecht","Lovilio","Mister choc","vitasia","Landjunker","NIXE,Lidl","Kania","Fin Carr\u00e9,//Property://,Lidl Stiftung & Co. KG,//Die Zugeh\u00f6rigkeit zu://,Schwarz Beteiligungs GmbH","Fin Carr\u00e9,//Property://,Lidl Stiftung & Co. KG,//Die Zugeh\u00f6rigkeit zu://,Schwarz Beteiligungs GmbH","Kania","Milbona","Milbona","J.D.Gross,Halloren Schokoladenfabrik AG","Milbona","Milbona","Milbona","Milbona","My Best Veggie","My Best Veggie","Golden Sun","Crownfield,LIDL","Riggano","bio","Moser-Roth,Aldi GmbH & Co. KG,Aldi Einkauf GmbH & Co. oHG","milfina, M Classic","Choceur,Hosta","Grandessa","Genuss der Saison","EDEKA","Puda","Paradiso","Oster Phantasie","Naturgut","Alpenhain","Trader Joe's","Scholetta,Aldi Einkauf GmbH & Co. oHG","Freihofer Gourmet,Aldi Einkauf GmbH & Co. oHG","Mein Veggie Tag","Milsani","GutBio","Trader Joe's","Ferrero,Nutella","Salakis","Lindt, Lindt Excellence","Lindt,Chocoladefabriken Lindt & Spr\u00fcngli AG,Lindt Excellence","Leerdammer","Leerdammer","Bonduelle","Bonduelle","Bonduelle","Haribo","Pr\u00e9sident","P\u00e8re Eug\u00e8ne","Pr\u00e9sident","Ponthier","Chavroux","Les anis de flavigny,Anis de Flavigny","Nesquik,Nestle","H\u00e4agen-Dasz","H\u00e4agen-Dazs","Aoste","Salakis","Nestle,KitKat","Sweet+Plus","Dr. Willi Knoll","Schneekoppe","Bertolli,Unilever","Bertolli","Pommersche,R\u00fcgenwalder M\u00fchle,R\u00fcgenwalder","R\u00fcgenwalder M\u00fchle","Grafschafter,Grafschafter Krautfabrik","Ritter Sport","Ritter Sport","Ritter Sport,Ritter Sport Bunte ...

# %% [markdown]
# ### Use marker-color to encode further information
# In order to map feature values to marker-colors, *Bokeh* provides
# * different types of [Color Mappers](https://bokeh.pydata.org/en/latest/docs/reference/models/mappers.html#). As the name suggests, a color mapper maps a value of a categorical or a numeric variable into a color of a specified color pallete.
# * a bunch of [Color Palettes](https://bokeh.pydata.org/en/latest/docs/reference/palettes.html).
#
# In the code-cells below the `LinearColorMapper` and the `viridis` color-pallete is applied. For the ColorMapper the color-pallete and the minimum- and maximum-value of the variable's value range must be defined. For the color-pallete the number of different colors must be defined (20 in the example below). In the `circle()`-method, the a dictionary must be assigned to the `color`-argument,
#
# ```color={'field': 'fat_100g', 'transform': mapper},```
#
# which defines
# * the dataframe-column for which values shall be mapped to color
# * the color-mapper object to be used.
#
#
# In order to understand which values are mapped to which colors a corresponding [ColorBar](https://bokeh.pydata.org/en/latest/docs/reference/models/annotations.html) can be added to the layout, as shown below:

# %%
#import modules for color - mapping:
from bokeh.palettes import magma,viridis
from bokeh.models.mappers import LinearColorMapper
from bokeh.models import ColumnDataSource,HoverTool, ColorBar

# %%
#create Color-Mapper object with specified color-pallete
mapper=LinearColorMapper(palette=viridis(20),low=germanFood["fat_100g"].min(),high=germanFood["fat_100g"].max())

# %%
#create ColorBar object
color_bar = ColorBar(color_mapper=mapper, location=(0, 0))

# %%
hover = HoverTool(tooltips = [("Productname","@product_name"),("Brand","@brands")], mode="mouse") #other modes: vline, hline
options = dict(plot_width=800, plot_height=500,
               tools=[hover,"crosshair,pan,wheel_zoom,box_zoom,box_select,lasso_select,reset"])

p = figure(title="Proteins vs. Carbohydrates", x_axis_label="carbohydrates/100g", y_axis_label="proteins/100g", **options)
p.circle("carbohydrates_100g","proteins_100g", size="normedEnergy", color={'field': 'fat_100g', 'transform': mapper}, alpha=0.8, source=source)
p.add_layout(color_bar, 'left')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="53e5986f-97f8-4a55-82c6-854c7b5f3e97"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("53e5986f-97f8-4a55-82c6-854c7b5f3e97");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("53e5986f-97f8-4a55-82c6-854c7b5f3e97");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '53e5986f-97f8-4a55-82c6-854c7b5f3e97' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d84087cc-2ac7-4f4b-91b9-15e4e7b074bc":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["brands","product_name","main_category","energy_100g","fat_100g","proteins_100g","salt_100g","carbohydrates_100g","sugars_100g","sodium_100g","saturated-fat_100g","normedEnergy","index"],"data":{"brands":["Candy Crush","Candy Crush","Del Monte","The Invisible Chef","The Invisible Chef","vitasia","Sun Snacks (Aldi S\u00fcd)","Bergader","Ikea","Freihofer Gourmet,Aldi Einkauf GmbH & Co. oHG","Moser-Roth,Aldi GmbH & Co. KG,Aldi Einkauf GmbH & Co. oHG","Moser-Roth,Aldi GmbH & Co. KG,Aldi Einkauf GmbH & Co. oHG","Scholetta,Aldi Einkauf GmbH & Co. oHG","Milbona","Combino","Freshona, Fresh & Easy","N\u00fcrnberger-Wein-Kellerei","Fin Carr\u00e9,Lidl Stiftung & Co. KG,Schwarz Beteiligungs GmbH,Solent GmbH","Saint Alby,Gebirgsj\u00e4ger","Envia,Milbona","Alesto","eridanous,Milbona","Alesto","Naturgut,Penny","Vitasia China","Bio Sonne,Soja Food","Combino","Naturgut,Giaguaro","J.D. Gross","Crownfield,Lidl","Milbona","Gutknecht","Lovilio","Mister choc","vitasia","Landjunker","NIXE,Lidl","Kania","Fin Carr\u00e9,//Property://,Lidl Stiftung & Co. KG,//Die Zugeh\u00f6rigkeit zu://,Schwarz Beteiligungs GmbH","Fin Carr\u00e9,//Property://,Lidl Stiftung & Co. KG,//Die Zugeh\u00f6rigkeit zu://,Schwarz Beteiligungs GmbH","Kania","Milbona","Milbona","J.D.Gross,Halloren Schokoladenfabrik AG","Milbona","Milbona","Milbona","Milbona","My Best Veggie","My Best Veggie","Golden Sun","Crownfield,LIDL","Riggano","bio","Moser-Roth,Aldi GmbH & Co. KG,Aldi Einkauf GmbH & Co. oHG","milfina, M Classic","Choceur,Hosta","Grandessa","Genuss der Saison","EDEKA","Puda","Paradiso","Oster Phantasie","Naturgut","Alpenhain","Trader Joe's","Scholetta,Aldi Einkauf GmbH & Co. oHG","Freihofer Gourmet,Aldi Einkauf GmbH & Co. oHG","Mein Veggie Tag","Milsani","GutBio","Trader Joe's","Ferrero,Nutella","Salakis","Lindt, Lindt Excellence","Lindt,Chocoladefabriken Lindt & Spr\u00fcngli AG,Lindt Excellence","Leerdammer","Leerdammer","Bonduelle","Bonduelle","Bonduelle","Haribo","Pr\u00e9sident","P\u00e8re Eug\u00e8ne","Pr\u00e9sident","Ponthier","Chavroux","Les anis de flavigny,Anis de Flavigny","Nesquik,Nestle","H\u00e4agen-Dasz","H\u00e4agen-Dazs","Aoste","Salakis","Nestle,KitKat","Sweet+Plus","Dr. Willi Knoll","Schneekoppe","Bertolli,Unilever","Bertolli","Pommersche,R\u00fcgenwalder M\u00fchle,R\u00fcgenwalder","R\u00fcgenwalder M\u00fchle","Grafschafter,Grafschafter Krautfabrik","Ritter Sport","Ritter Sport","Ritter Sport,Ritter Sport Bunte Vielfalt","L\u00e4tta","Dr. Oetker","Lindt","Lindt","K\u00f6ln Cerealien","K\u00f6lln Balance","Mounthagen","Schapfen M\u00fchle","Leicht & Cross","Leicht & Cross","Leicht & Cross","Leicht & Cross","Haribo","Dr. Oetker,Pizzaburger","Kerrygold","Wiltmann","Me\u00dfmer","M\u00f6venpick","Uncle Ben's","Ehrmann","Ehrmann","Elinas","Kellogg's","Rabenhorst plus","Soja Fit","Berief","Barney's Best","Barney's Best","Bio-Zentrale","Biovegan","Biovegan","Biovegan","Rosengarten","Rapunzel","Rapunzel,Klare Suppe","Rapunzel","Bergader","Bergader","Bergader","TOP MARE","Multipower","Develey","Lambertz","Maryland","M\u00f6venpick","Seeberger","Seeberger","Seeberger","Seeberger","FRoSTA","FRoSTA","FRoSTA","FRoSTA","FRoSTA","FRoSTA","FRoSTA","FRoSTA","FRoSTA","FRoSTA","Seitenbacher","Kinder","Kinder,Ferrero","Ferrero,duplo","Ferrero,Duplo","Nutella,Ferrero","Kinder,Ferrero","Leicht & Cross","Leicht & Cross","S\u00f6bbeke","Milch-Schnitte,Ferrero","Milch-Schnitte,Ferrero","Dietz","Mazzetti","Linda natura","Lieken","windau","dm Bio","dm Bio","dm Bio","dm Bio","dm Bio","Bounty,Mars","M&M's","Schwartau","Corny,Corny Sport","coop Feine Lebensmittel","Neumarkter Lammsbr\u00e4u","Nick","GEPA","Demeter","Alb-Natur,Alb Gold","Davert","Davert","Davert","Davert","Raab Vitalfood","Vivil","nippon,Hosta","dennree","Gustoni","dennree","dennree","\u00d6kodorf Brodowin","Naturata","J\u00fctro Bio,J\u00fctro","Nestle,Kitkat","bioladen","biola ...

# %% [markdown]
# ## Linking of Plots
# Sometimes one dataset is visualized in multiple plots, each providing a different perspective on or different features of the given dataset. In this case a linking of the related plots may be advantageous. With linking one or more data points can be selected in one plot and they get highlighted in all joint plots.
#
# For displaying multiple joint plots usually Bokeh's `gridplot()`-method is applied and the joint plots all apply the same *data source* of type `ColumnDataSource`:

# %%
from bokeh.layouts import gridplot
source = ColumnDataSource(germanFood)

options = dict(plot_width=500, plot_height=500,
               tools="pan,wheel_zoom,box_zoom,box_select,lasso_select,reset")

p1 = figure(title="energy vs fat", **options)
p1.circle("fat_100g","energy_100g", color="blue", size=6, source=source)

p2 = figure(title="energy vs protein",y_range=p1.y_range, **options)
p2.diamond("proteins_100g","energy_100g", color="green", size=6, source=source)
#p3.circle("proteins_100g","energy_100g", size="sugars_100g", fill_color="fat_100g", source=source)

p3 = figure(title="energy vs sugar",y_range=p1.y_range, **options)
p3.square("sugars_100g","energy_100g", color="red", size=6, source=source)

p4 = figure(title="energy vs carbohydrates",y_range=p1.y_range, **options)
p4.triangle("carbohydrates_100g","energy_100g",color="orange", size=6, source=source)

p = gridplot([[ p1, p2],[ p3, p4]], toolbar_location="right")

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d5b13dcc-77cb-4384-86c7-fc6b03b101f7"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("d5b13dcc-77cb-4384-86c7-fc6b03b101f7");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d5b13dcc-77cb-4384-86c7-fc6b03b101f7");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd5b13dcc-77cb-4384-86c7-fc6b03b101f7' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"465ba0c9-b2b5-4b31-bc05-1254f3774436":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"xs_units":"screen","ys_units":"screen"},"id":"635122dd-4634-498d-a286-b2c6d8823f8a","type":"PolyAnnotation"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"16fef738-eea5-45e0-aa4b-ab0e4ae1732c","type":"BoxAnnotation"},{"attributes":{"callback":null},"id":"2e57beec-5375-408b-9861-9d3e3116a163","type":"DataRange1d"},{"attributes":{},"id":"d226e5d4-0ed2-4272-9baf-61500007bd36","type":"ResetTool"},{"attributes":{"overlay":{"id":"16fef738-eea5-45e0-aa4b-ab0e4ae1732c","type":"BoxAnnotation"}},"id":"a7d4e99c-4b57-4cad-bcda-6cf0c146c9d0","type":"BoxZoomTool"},{"attributes":{"callback":null,"column_names":["brands","product_name","main_category","energy_100g","fat_100g","proteins_100g","salt_100g","carbohydrates_100g","sugars_100g","sodium_100g","saturated-fat_100g","normedEnergy","index"],"data":{"brands":["Candy Crush","Candy Crush","Del Monte","The Invisible Chef","The Invisible Chef","vitasia","Sun Snacks (Aldi S\u00fcd)","Bergader","Ikea","Freihofer Gourmet,Aldi Einkauf GmbH & Co. oHG","Moser-Roth,Aldi GmbH & Co. KG,Aldi Einkauf GmbH & Co. oHG","Moser-Roth,Aldi GmbH & Co. KG,Aldi Einkauf GmbH & Co. oHG","Scholetta,Aldi Einkauf GmbH & Co. oHG","Milbona","Combino","Freshona, Fresh & Easy","N\u00fcrnberger-Wein-Kellerei","Fin Carr\u00e9,Lidl Stiftung & Co. KG,Schwarz Beteiligungs GmbH,Solent GmbH","Saint Alby,Gebirgsj\u00e4ger","Envia,Milbona","Alesto","eridanous,Milbona","Alesto","Naturgut,Penny","Vitasia China","Bio Sonne,Soja Food","Combino","Naturgut,Giaguaro","J.D. Gross","Crownfield,Lidl","Milbona","Gutknecht","Lovilio","Mister choc","vitasia","Landjunker","NIXE,Lidl","Kania","Fin Carr\u00e9,//Property://,Lidl Stiftung & Co. KG,//Die Zugeh\u00f6rigkeit zu://,Schwarz Beteiligungs GmbH","Fin Carr\u00e9,//Property://,Lidl Stiftung & Co. KG,//Die Zugeh\u00f6rigkeit zu://,Schwarz Beteiligungs GmbH","Kania","Milbona","Milbona","J.D.Gross,Halloren Schokoladenfabrik AG","Milbona","Milbona","Milbona","Milbona","My Best Veggie","My Best Veggie","Golden Sun","Crownfield,LIDL","Riggano","bio","Moser-Roth,Aldi GmbH & Co. KG,Aldi Einkauf GmbH & Co. oHG","milfina, M Classic","Choceur,Hosta","Grandessa","Genuss der Saison","EDEKA","Puda","Paradiso","Oster Phantasie","Naturgut","Alpenhain","Trader Joe's","Scholetta,Aldi Einkauf GmbH & Co. oHG","Freihofer Gourmet,Aldi Einkauf GmbH & Co. oHG","Mein Veggie Tag","Milsani","GutBio","Trader Joe's","Ferrero,Nutella","Salakis","Lindt, Lindt Excellence","Lindt,Chocoladefabriken Lindt & Spr\u00fcngli AG,Lindt Excellence","Leerdammer","Leerdammer","Bonduelle","Bonduelle","Bonduelle","Haribo","Pr\u00e9sident","P\u00e8re Eug\u00e8ne","Pr\u00e9sident","Ponthier","Chavroux","Les anis de flavigny,Anis de Flavigny","Nesquik,Nestle","H\u00e4agen-Dasz","H\u00e4agen-Dazs","Aoste","Salakis","Nestle,KitKat","Sweet+Plus","Dr. Willi Knoll","Schneekoppe","Bertolli,Unilever","Bertolli","Pommersche,R\u00fcgenwalder M\u00fchle,R\u00fcgenwalder","R\u00fcgenwalder M\u00fchle","Grafschafter,Grafschafter Krautfabrik","Ritter Sport","Ritter Sport","Ritter Sport,Ritter Sport Bunte Vielfalt","L\u00e4tta","Dr. Oetker","Lindt","Lindt","K\u00f6ln Cerealien","K\u00f6lln Balance","Mounthagen","Schapfen M\u00fchle","Leicht & Cross","Leicht & Cross","Leicht & Cross","Leicht & Cross","Haribo","Dr. Oetker,Pizzaburger","Kerrygold","Wiltmann","Me\u00dfmer","M\u00f6venpick","Uncle Ben's","Ehrmann","Ehrmann","Elinas","Kellogg's","Rabenhorst plus","Soja Fit","Berief","Barney ...

# %% [markdown]
# In the plots above different marker-symbols have been applied. There exist much more markers and other chart-types, that can be used to draw data. See for example [Bokeh, Plotting with basic glyphs](http://bokeh.pydata.org/en/latest/docs/user_guide/plotting.html#userguide-plotting) or [bokeh.plotting reference](https://bokeh.pydata.org/en/latest/docs/reference/plotting.html). Some of the most frequently applied chart-types are demonstrated in the following section.

# %% [markdown]
# ## Other plot types
# ### Bar Plots
# Bar plots are frequently applied, e.g. for the viusalisations of value-frequencies (histograms). For example, in the food-dataset, used in this notebook, one may be interested in the frequency of each category (column `main_category` in the dataframe). For this we first apply the *Pandas*-method `groupby()` for summarizing all products by their `main_category`. Then for all categories with more than one product, a histogram is plotted:

# %%
categoryCount=germanFood.groupby(by="main_category")["brands"].count()

# %%
cats=categoryCount[categoryCount>1]

# %%
px = figure(title="Categories with more than one product",x_range=cats.index.tolist(),plot_width=700)
px.vbar(cats.index.tolist(),bottom=0,top=cats.values.tolist(),color="blue",width=0.8,alpha=0.6)
px.xaxis.major_label_orientation = "vertical"
show(px)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="226016eb-4dbf-4baa-bbe2-e316c95bb4ec"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("226016eb-4dbf-4baa-bbe2-e316c95bb4ec");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("226016eb-4dbf-4baa-bbe2-e316c95bb4ec");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '226016eb-4dbf-4baa-bbe2-e316c95bb4ec' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"15f5fc0a-baaa-4ef9-99c1-22c04f197726":{"roots":{"references":[{"attributes":{"plot":null,"text":"Categories with more than one product"},"id":"0f59d6f4-5912-4e5e-aec1-66edbfdc6e1c","type":"Title"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"top":{"field":"top"},"width":{"value":0.8},"x":{"field":"x"}},"id":"913743e6-8e09-42df-a93f-ca98cbd2530c","type":"VBar"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"847fa9a9-4d77-4fa1-92ff-181f1b40a055","type":"BoxAnnotation"},{"attributes":{},"id":"8e5eee17-8957-4bc3-8d41-8c9a86e10db7","type":"BasicTickFormatter"},{"attributes":{},"id":"b1c9e02b-9f40-4b31-bf8e-68ec99c4ef9a","type":"WheelZoomTool"},{"attributes":{"callback":null,"column_names":["x","top"],"data":{"top":[2,2,4,38,2,48,8,9,2,9,5,24,5,8,2,3,159,11,3,16,72,3],"x":["de:knusperbrot","de:snacks","en:baby-foods","en:beverages","en:canned-foods","en:dairies","en:desserts","en:dietary-supplements","en:fresh-foods","en:frozen-foods","en:fruit-juices","en:groceries","en:meals","en:meats","en:pancake-mix","en:pickles","en:plant-based-foods-and-beverages","en:salty-snacks","en:seafood","en:spreads","en:sugary-snacks","en:sweeteners"]}},"id":"5586ef9c-a317-4679-b7e2-b6991fedaeaa","type":"ColumnDataSource"},{"attributes":{"callback":null,"factors":["de:knusperbrot","de:snacks","en:baby-foods","en:beverages","en:canned-foods","en:dairies","en:desserts","en:dietary-supplements","en:fresh-foods","en:frozen-foods","en:fruit-juices","en:groceries","en:meals","en:meats","en:pancake-mix","en:pickles","en:plant-based-foods-and-beverages","en:salty-snacks","en:seafood","en:spreads","en:sugary-snacks","en:sweeteners"]},"id":"ac62805d-8cca-4a96-9d2b-8c493fc624ab","type":"FactorRange"},{"attributes":{"source":{"id":"5586ef9c-a317-4679-b7e2-b6991fedaeaa","type":"ColumnDataSource"}},"id":"9697a49c-b0df-47b1-bd6e-867221ac458e","type":"CDSView"},{"attributes":{},"id":"537e2fe1-252a-4cae-8f87-39c52a20aa10","type":"BasicTicker"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"0994ecc8-3538-4fbb-bab2-90685860b20f","type":"PanTool"},{"id":"b1c9e02b-9f40-4b31-bf8e-68ec99c4ef9a","type":"WheelZoomTool"},{"id":"c47fe066-fc39-49fa-b9a0-574193d76ed5","type":"BoxZoomTool"},{"id":"70dc3cdd-ca3a-40e9-9ae2-554bb7cb5f9b","type":"SaveTool"},{"id":"a86be1bc-4d8d-44ad-bb12-cc036ba4b1e1","type":"ResetTool"},{"id":"92fc534e-402d-48c6-bb41-2f2b90e6d7f9","type":"HelpTool"}]},"id":"70746add-b912-4c8a-b11f-258c84edeb2c","type":"Toolbar"},{"attributes":{"fill_alpha":{"value":0.6},"fill_color":{"value":"blue"},"line_alpha":{"value":0.6},"line_color":{"value":"blue"},"top":{"field":"top"},"width":{"value":0.8},"x":{"field":"x"}},"id":"07bc1c18-54a7-41de-8e96-db21937719b8","type":"VBar"},{"attributes":{"data_source":{"id":"5586ef9c-a317-4679-b7e2-b6991fedaeaa","type":"ColumnDataSource"},"glyph":{"id":"07bc1c18-54a7-41de-8e96-db21937719b8","type":"VBar"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"913743e6-8e09-42df-a93f-ca98cbd2530c","type":"VBar"},"selection_glyph":null,"view":{"id":"9697a49c-b0df-47b1-bd6e-867221ac458e","type":"CDSView"}},"id":"c822fd38-948a-4f9c-a4ee-040e1b6f2ef5","type":"GlyphRenderer"},{"attributes":{"formatter":{"id":"8e5eee17-8957-4bc3-8d41-8c9a86e10db7","type":"BasicTickFormatter"},"plot":{"id":"249c6935-3349-4b4e-8d1a-b40aecde6da5","subtype":"Figure","type":"Plot"},"ticker":{"id":"537e2fe1-252a-4cae-8f87-39c52a20aa10","type":"BasicTicker"}},"id":"fc7398e7-1af3-4d51-b908-ff91939f8029","type":"LinearAxis"},{"attributes":{},"id":"0994ecc8-3538-4fbb-bab2-90685860b20f","type" ...
